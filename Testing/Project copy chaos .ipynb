# %%
import pandas as pd

# %%
data = pd.read_csv("data\cwurData.csv")
# data = pd.read_csv("cwurData.csv")
data = data[data["country"] == "Germany"]

# %%
regex = "(University of [a-zA-ZüäöÖÄÜ]+)"
data["city"] = data["institution"].str.extract(regex)
data["city"] = data["city"].str.replace("University of ", "")
data.loc[data["city"].str.contains("technology", case = False, na = False), "city"] = pd.NA

# %%
data["city"].value_counts(dropna = False)
# Out:
# NaN           30
# Munich         7
# Berlin         6
# Heidelberg     4
# Mannheim       2
# Siegen         2
# Osnabrück      2
# Greifswald     2
# Hohenheim      2
# Lübeck         2
# Jena           2
# Bremen         2
# Bayreuth       2
# Potsdam        2
# Halle          2
# Hanover        2
# Rostock        2
# Konstanz       2
# Dortmund       2
# Augsburg       2
# Regensburg     2
# Marburg        2
# Münster        2
# Bonn           2
# Freiburg       2
# Tübingen       2
# Göttingen      2
# Hamburg        2
# Cologne        2
# Erlangen       2
# Duisburg       2
# Würzburg       2
# Kiel           2
# Mainz          2
# Düsseldorf     2
# Ulm            2
# Stuttgart      2
# Oldenburg      2
# Name: city, dtype: int64

# %%
data[data["institution"].str.contains("Osnabr")]
# Out:
#       world_rank              institution  country  national_rank  \
# 1108         909  University of Osnabrück  Germany             53
# 2075         876  University of Osnabrück  Germany             54
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# 1108                   355                478                 210
# 2075                   367                567                 218
#
#       publications  influence  citations  broad_impact  patents  score  year  \
# 1108           841        628        800         849.0      737  44.38  2014
# 2075           844        654        511         826.0      871  44.15  2015
#
#            city
# 1108  Osnabrück
# 2075  Osnabrück

# %%
#filt.describe()

# %%
filt = data[(data["country"] == "Germany") & (data["year"] <= 2014)]
filt
# Out:
#       world_rank                                   institution  country  \
# 81            82        Ruprecht Karl University of Heidelberg  Germany
# 82            83        Ludwig Maximilian University of Munich  Germany
# 89            90                Technical University of Munich  Germany
# 166           67        Ludwig Maximilian University of Munich  Germany
# 178           79        Ruprecht Karl University of Heidelberg  Germany
# 281           82        Ludwig Maximilian University of Munich  Germany
# 288           89        Ruprecht Karl University of Heidelberg  Germany
# 297           98                            University of Bonn  Germany
# 298           99                Technical University of Munich  Germany
# 334          135          Albert Ludwig University of Freiburg  Germany
# 356          157                 Humboldt University of Berlin  Germany
# 357          158                     Free University of Berlin  Germany
# ...

# %%
filt.describe()
# Out:
#        world_rank  national_rank  quality_of_education  alumni_employment  \
# count   60.000000      60.000000             60.000000          60.000000
# mean   373.850000      25.816667            250.433333         371.050000
# std    255.758084      16.979042            129.479972         143.110651
# min     67.000000       1.000000             23.000000         101.000000
# 25%    176.500000      10.750000             98.500000         275.750000
# 50%    299.500000      25.500000            349.000000         478.000000
# 75%    502.000000      40.250000            355.000000         478.000000
# max    966.000000      55.000000            355.000000         478.000000
#
#        quality_of_faculty  publications   influence   citations  broad_impact  \
# count           60.000000     60.000000   60.000000   60.000000     55.000000
# mean           173.616667    358.466667  319.266667  368.883333    354.200000
# ...

# %%
data.drop(columns=["publications", "influence","citations","broad_impact","patents", "score","alumni_employment"], inplace=True)

# %%
data
# Out:
#       world_rank                             institution  country  \
# 81            82  Ruprecht Karl University of Heidelberg  Germany
# 82            83  Ludwig Maximilian University of Munich  Germany
# 89            90          Technical University of Munich  Germany
# 166           67  Ludwig Maximilian University of Munich  Germany
# 178           79  Ruprecht Karl University of Heidelberg  Germany
# ...          ...                                     ...      ...
# 1992         793                 University of Hohenheim  Germany
# 2000         801                 University of Oldenburg  Germany
# 2056         857                    University of Siegen  Germany
# 2075         876                 University of Osnabrück  Germany
# 2101         902                  University of Mannheim  Germany
#
#       national_rank  quality_of_education  quality_of_faculty  year  \
# 81                1                    87                  52  2012
# ...

# %%
data["city"]
# Out:
# 81      Heidelberg
# 82          Munich
# 89          Munich
# 166         Munich
# 178     Heidelberg
#            ...
# 1992     Hohenheim
# 2000     Oldenburg
# 2056        Siegen
# 2075     Osnabrück
# 2101      Mannheim
# Name: city, Length: 115, dtype: object

# %%
data.to_excel("data/city.xlsx")

# %%
cities=pd.read_excel("data/city.xlsx")

# %%
cities.rename(columns={"Unnamed: 0":"old_index"}, inplace=True)

# %%
cities
# Out:
#      old_index  world_rank                             institution  country  \
# 0           81          82  Ruprecht Karl University of Heidelberg  Germany
# 1           82          83  Ludwig Maximilian University of Munich  Germany
# 2           89          90          Technical University of Munich  Germany
# 3          166          67  Ludwig Maximilian University of Munich  Germany
# 4          178          79  Ruprecht Karl University of Heidelberg  Germany
# ..         ...         ...                                     ...      ...
# 110       1992         793                 University of Hohenheim  Germany
# 111       2000         801                 University of Oldenburg  Germany
# 112       2056         857                    University of Siegen  Germany
# 113       2075         876                 University of Osnabrück  Germany
# 114       2101         902                  University of Mannheim  Germany
#
# ...

# %%
cities["city"].value_counts(dropna = False)
# Out:
# NaN           30
# Munich         7
# Berlin         6
# Heidelberg     4
# Mannheim       2
# Siegen         2
# Osnabrück      2
# Greifswald     2
# Hohenheim      2
# Lübeck         2
# Jena           2
# Bremen         2
# Bayreuth       2
# Potsdam        2
# Halle          2
# Hanover        2
# Rostock        2
# Konstanz       2
# Dortmund       2
# Augsburg       2
# Regensburg     2
# Marburg        2
# Münster        2
# Bonn           2
# Freiburg       2
# Tübingen       2
# Göttingen      2
# Hamburg        2
# Cologne        2
# Erlangen       2
# Duisburg       2
# Würzburg       2
# Kiel           2
# Mainz          2
# Düsseldorf     2
# Ulm            2
# Stuttgart      2
# Oldenburg      2
# Name: city, dtype: int64

# %% [markdown]
# Appartment Data Set Combination

# %% [markdown]
# regio1
# serviceCharge
# balcony
# telekomUploadSpeed
# totalRent
# yearConstructed
# hasKitchen
# cellar
# baseRent
# livingSpace
# petsAllowed
# lift
# noRooms
# garden
# regio2
# regio3

# %%
appartments = pd.read_csv("data/immo_data.csv", usecols = ['regio1','serviceCharge','balcony','telekomUploadSpeed','totalRent', "yearConstructed", "hasKitchen","cellar", "baseRent","livingSpace","petsAllowed", "lift","noRooms", "garden", "regio2", "regio3" ])

# %%
appartments
# Out:
#                      regio1  serviceCharge  balcony  telekomUploadSpeed  \
# 0       Nordrhein_Westfalen         245.00    False                10.0
# 1           Rheinland_Pfalz         134.00     True                10.0
# 2                   Sachsen         255.00     True                 2.4
# 3                   Sachsen          58.15     True                40.0
# 4                    Bremen         138.00     True                 NaN
# ...                     ...            ...      ...                 ...
# 268845               Bayern          90.00     True                10.0
# 268846               Hessen         220.00     True                 NaN
# 268847               Hessen         220.00     True                40.0
# 268848  Nordrhein_Westfalen         175.00     True                 NaN
# 268849               Hessen         315.00     True                 NaN
#
#         totalRent  yearConstructed  hasKitchen  cellar  baseRent  livingSpace  \
# ...

# %%
appartments.set_index("regio2", inplace=True)

# %%
appartments.sort_index(inplace=True)

# %%
appartments["petsAllowed"].unique()
# Out:
# array([nan, 'no', 'negotiable', 'yes'], dtype=object)

# %%
appartments.dtypes
# Out:
# regio1                 object
# serviceCharge         float64
# balcony                  bool
# telekomUploadSpeed    float64
# totalRent             float64
# yearConstructed       float64
# hasKitchen               bool
# cellar                   bool
# baseRent              float64
# livingSpace           float64
# petsAllowed            object
# lift                     bool
# noRooms               float64
# garden                   bool
# regio3                 object
# dtype: object

# %%
#Only for logic. No actual Code.

appcount=0
regio2=


if regio2==regio2
    sumOfTotal=totalRent+sumOfTotal
    appcount=citycount+1
else
    sumOfTotal:appcount ="regio2"av
    regio2=nextregio2
    "start again"
# Out:
#   File "C:\Users\Marek\AppData\Local\Temp/ipykernel_1724/1549976308.py", line 4
#     regio2=
#            ^
# SyntaxError: invalid syntax

# %%
appartments.head(50)
# Out:
#                      regio1  serviceCharge  balcony  telekomUploadSpeed  \
# regio2
# Aachen  Nordrhein_Westfalen         115.00    False                10.0
# Aachen  Nordrhein_Westfalen         175.00     True                40.0
# Aachen  Nordrhein_Westfalen         130.00    False                 2.4
# Aachen  Nordrhein_Westfalen         100.00    False                 2.4
# Aachen  Nordrhein_Westfalen         146.00     True                40.0
# Aachen  Nordrhein_Westfalen         175.00     True                40.0
# Aachen  Nordrhein_Westfalen         120.00    False                 NaN
# Aachen  Nordrhein_Westfalen         160.00     True                10.0
# Aachen  Nordrhein_Westfalen         100.00     True                 2.4
# Aachen  Nordrhein_Westfalen            NaN     True                 NaN
# Aachen  Nordrhein_Westfalen         100.00     True                40.0
# Aachen  Nordrhein_Westfalen          95.00    False                 2.4
# ...

# %% [markdown]
# Cultural Data

# %%
cultural= pd.read_excel("data/cultural_data.xlsx")
# Out:
# C:\Users\Marek\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
population_data=pd.read_csv("data/Deutschland_Cities.csv")

# %%
population_data
# Out:
#                        city      lat      lng  country iso2  \
# 0                    Berlin  52.5167  13.3833  Germany   DE
# 1                   Hamburg  53.5500  10.0000  Germany   DE
# 2                    Munich  48.1372  11.5755  Germany   DE
# 3                   Cologne  50.9422   6.9578  Germany   DE
# 4                 Frankfurt  50.1136   8.6797  Germany   DE
# ..                      ...      ...      ...      ...  ...
# 607               Rotenburg  53.0851   9.3879  Germany   DE
# 608               Karlstadt  49.9603   9.7724  Germany   DE
# 609                Neustadt  49.5656   8.8437  Germany   DE
# 610                 Homberg  51.0299   9.4026  Germany   DE
# 611  Garmisch-Partenkirchen  47.4985  11.1044  Germany   DE
#
#                  admin_name  capital  population  population_proper
# 0                    Berlin  primary   3644826.0          3644826.0
# 1                   Hamburg    admin   1841179.0          1841179.0
# ...

# %% [markdown]
# Little Test

# %%
rent=0
for appartments["regio2"] == cities["city"]:
    rent= rent+appartments["baseRent"]
else:
    print("Ups")
# Out:
#   File "C:\Users\Marek\AppData\Local\Temp/ipykernel_32020/2752748412.py", line 2
#     for appartments["regio2"] == cities["city"]:
#                                                ^
# SyntaxError: invalid syntax

# %%
sum(baseRent per City)/len(baseRent per City) # For Mean

# %%
sum(baseRent per City)

# %%
cfilt= appartments["regio2"]=cities["city"]
appartments[cfilt].mean()
appartments[cfilt].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1724/3529056619.py in <module>
#       1 cfilt= appartments["regio2"]=cities["city"]
# ----> 2 appartments[cfilt].mean()
#       3 appartments[cfilt].sum()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
# ...

# %%
appartments.groupby(["index"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1724/3553306446.py in <module>
# ----> 1 appartments.groupby(["index"])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     887             from pandas.core.groupby.grouper import get_grouper
#     888
# ...

# %%
appartments.index.unique()
# Out:
# Index(['Aachen', 'Aachen_Kreis', 'Ahrweiler_Kreis', 'Aichach_Friedberg_Kreis',
#        'Alb_Donau_Kreis', 'Altenburger_Land_Kreis',
#        'Altenkirchen_Westerwald_Kreis', 'Altmarkkreis_Salzwedel',
#        'Altötting_Kreis', 'Alzey_Worms_Kreis',
#        ...
#        'Wolfsburg', 'Worms', 'Wunsiedel_im_Fichtelgebirge_Kreis', 'Wuppertal',
#        'Würzburg', 'Würzburg_Kreis', 'Zollernalbkreis', 'Zweibrücken',
#        'Zwickau', 'Zwickau_Kreis'],
#       dtype='object', name='regio2', length=419)

# %%
cities["city"].unique
# Out:
# <bound method Series.unique of 0      Heidelberg
# 1          Munich
# 2          Munich
# 3          Munich
# 4      Heidelberg
#           ...
# 110     Hohenheim
# 111     Oldenburg
# 112        Siegen
# 113     Osnabrück
# 114      Mannheim
# Name: city, Length: 115, dtype: object>

# %%
app_city=appartments.groupby(["regio2"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1724/2732779293.py in <module>
# ----> 1 app_city=appartments.groupby(["regio2"])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     887             from pandas.core.groupby.grouper import get_grouper
#     888
# ...

# %%
app_city.get_group("Aachen")
# Out:
#                      regio1  serviceCharge  balcony  telekomUploadSpeed  \
# regio2
# Aachen  Nordrhein_Westfalen          115.0    False                10.0
# Aachen  Nordrhein_Westfalen          175.0     True                40.0
# Aachen  Nordrhein_Westfalen          130.0    False                 2.4
# Aachen  Nordrhein_Westfalen          100.0    False                 2.4
# Aachen  Nordrhein_Westfalen          146.0     True                40.0
# ...                     ...            ...      ...                 ...
# Aachen  Nordrhein_Westfalen           90.0     True                40.0
# Aachen  Nordrhein_Westfalen          170.0    False                40.0
# Aachen  Nordrhein_Westfalen          135.0    False                 2.4
# Aachen  Nordrhein_Westfalen          140.0     True                 2.4
# Aachen  Nordrhein_Westfalen           70.0     True                 2.4
#
#         totalRent  yearConstructed  hasKitchen  cellar  baseRent  livingSpace  \
# regio2
# ...

# %%
app_city["petsAllowed"].value_counts()
# Out:
# regio2         petsAllowed
# Aachen         no              709
#                negotiable      470
#                yes              30
# Aachen_Kreis   negotiable      343
#                no              272
#                               ...
# Zwickau        yes              94
#                no               35
# Zwickau_Kreis  negotiable     1168
#                no               90
#                yes              58
# Name: petsAllowed, Length: 1235, dtype: int64

# %%
appartments["petsAllowed"].value_counts()
# Out:
# negotiable    91970
# no            51991
# yes           10316
# Name: petsAllowed, dtype: int64

# %%
cities.dtypes
# Out:
# old_index                int64
# world_rank               int64
# institution             object
# country                 object
# national_rank            int64
# quality_of_education     int64
# quality_of_faculty       int64
# year                     int64
# city                    object
# dtype: object

# %%
appartments
# Out:
#                             regio1  serviceCharge  balcony  \
# regio2
# Aachen         Nordrhein_Westfalen          115.0    False
# Aachen         Nordrhein_Westfalen          175.0     True
# Aachen         Nordrhein_Westfalen          130.0    False
# Aachen         Nordrhein_Westfalen          100.0    False
# Aachen         Nordrhein_Westfalen          146.0     True
# ...                            ...            ...      ...
# Zwickau_Kreis              Sachsen           51.0    False
# Zwickau_Kreis              Sachsen          110.0    False
# Zwickau_Kreis              Sachsen          154.0     True
# Zwickau_Kreis              Sachsen          150.0     True
# Zwickau_Kreis              Sachsen          150.0     True
#
#                telekomUploadSpeed  totalRent  yearConstructed  hasKitchen  \
# regio2
# Aachen                       10.0     475.50           1983.0       False
# Aachen                       40.0     755.00              NaN        True
# ...

# %%
appartments["regio2"]=appartments["regio2"].apply(lambda x: x.lower())

# %%
appartments["regio2"]=appartments["regio2"].str.replace(" ", "_")
appartments

# %%
app_city["cellar"].value_counts().loc[cities["city"].unique()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10436/3580259942.py in <module>
# ----> 1 app_city["cellar"].value_counts().loc[cities["city"].unique()]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# ...

# %%
appartments.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1724/2500526323.py in <module>
# ----> 1 appartments.reset_index(inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5797                     )
#    5798
# -> 5799                 new_obj.insert(0, name, level_values)
#    5800
#    5801         new_obj.index = new_index
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    4412         if not allow_duplicates and column in self.columns:
# ...

# %%
meanofcity=app_city["totalRent"].mean()   #.loc["Aachen"]
meanofcity
# Out:
# regio2
# Aachen                      829.472950
# Aachen_Kreis                766.717735
# Ahrweiler_Kreis             811.195740
# Aichach_Friedberg_Kreis    1037.368621
# Alb_Donau_Kreis             894.634437
#                               ...
# Würzburg_Kreis              856.139301
# Zollernalbkreis             823.415200
# Zweibrücken                 605.617021
# Zwickau                     508.105842
# Zwickau_Kreis               456.012759
# Name: totalRent, Length: 419, dtype: float64

# %%
cities["city"]=cities["city"].astype(str)
# Out:
# old_index                int64
# world_rank               int64
# institution             object
# country                 object
# national_rank            int64
# quality_of_education     int64
# quality_of_faculty       int64
# year                     int64
# city                    object
# dtype: object

# %%
app_city["totalRent"].apply(lambda x: x.str.contains(cities["city"]).mean())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10436/3999865779.py in <module>
# ----> 1 app_city["totalRent"].apply(lambda x: x.str.contains(cities["city"]).mean())
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in apply(self, func, *args, **kwargs)
#     221     )
#     222     def apply(self, func, *args, **kwargs):
# --> 223         return super().apply(func, *args, **kwargs)
#     224
#     225     @doc(_agg_template, examples=_agg_examples_doc, klass="Series")
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#    1273         with option_context("mode.chained_assignment", None):
#    1274             try:
# -> 1275                 result = self._python_apply_general(f, self._selected_obj)
#    1276             except TypeError:
#    1277                 # gh-20949
#
# ...

# %%
import numpy as np

# %%
cities["test"]=

# %%
cities.fillna("missing")
appartments.fillna("missing")
# Out:
#                regio2               regio1 serviceCharge  balcony  \
# 0              Aachen  Nordrhein_Westfalen         115.0    False
# 1              Aachen  Nordrhein_Westfalen         175.0     True
# 2              Aachen  Nordrhein_Westfalen         130.0    False
# 3              Aachen  Nordrhein_Westfalen         100.0    False
# 4              Aachen  Nordrhein_Westfalen         146.0     True
# ...               ...                  ...           ...      ...
# 268845  Zwickau_Kreis              Sachsen          51.0    False
# 268846  Zwickau_Kreis              Sachsen         110.0    False
# 268847  Zwickau_Kreis              Sachsen         154.0     True
# 268848  Zwickau_Kreis              Sachsen         150.0     True
# 268849  Zwickau_Kreis              Sachsen         150.0     True
#
#        telekomUploadSpeed totalRent yearConstructed  hasKitchen  cellar  \
# 0                    10.0     475.5          1983.0       False    True
# ...

# %%
conditions=[cities["city"]]
conditions
# Out:
# [0      Heidelberg
#  1          Munich
#  2          Munich
#  3          Munich
#  4      Heidelberg
#            ...
#  110     Hohenheim
#  111     Oldenburg
#  112        Siegen
#  113     Osnabrück
#  114      Mannheim
#  Name: city, Length: 115, dtype: object]

# %%
values=[appartments["regio2"]]
values
# Out:
# [0                Aachen
#  1                Aachen
#  2                Aachen
#  3                Aachen
#  4                Aachen
#                ...
#  268845    Zwickau_Kreis
#  268846    Zwickau_Kreis
#  268847    Zwickau_Kreis
#  268848    Zwickau_Kreis
#  268849    Zwickau_Kreis
#  Name: regio2, Length: 268850, dtype: object]

# %%
cities["test"]=np.select(conditions, values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32020/1935008786.py in <module>
# ----> 1 cities["test"]=np.select(conditions, values)
#
# <__array_function__ internals> in select(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in select(condlist, choicelist, default)
#     687     for i, cond in enumerate(condlist):
#     688         if cond.dtype.type is not np.bool_:
# --> 689             raise TypeError(
#     690                 'invalid entry {} in condlist: should be boolean ndarray'.format(i))
#     691
#
# TypeError: invalid entry 0 in condlist: should be boolean ndarray

# %%
Yo=0
Noe=0
if app_city==cities["city"]:
    Yo=Yo+1
else:
    Noe=Noe+1

print(Yo)
print(Noe)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10436/78236944.py in <module>
#       1 Yo=0
#       2 Noe=0
# ----> 3 if app_city==cities["city"]:
#       4     Yo=Yo+1
#       5 else:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
app_city["totalRent"].groupby(cities["city"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16352/2714111822.py in <module>
# ----> 1 app_city["totalRent"].groupby(cities["city"])
#
# NameError: name 'app_city' is not defined

# %%
cities.drop(columns=["test"], inplace=True)

# %%
cities
# Out:
#      old_index  world_rank                             institution  country  \
# 0           81          82  Ruprecht Karl University of Heidelberg  Germany
# 1           82          83  Ludwig Maximilian University of Munich  Germany
# 2           89          90          Technical University of Munich  Germany
# 3          166          67  Ludwig Maximilian University of Munich  Germany
# 4          178          79  Ruprecht Karl University of Heidelberg  Germany
# ..         ...         ...                                     ...      ...
# 110       1992         793                 University of Hohenheim  Germany
# 111       2000         801                 University of Oldenburg  Germany
# 112       2056         857                    University of Siegen  Germany
# 113       2075         876                 University of Osnabrück  Germany
# 114       2101         902                  University of Mannheim  Germany
#
# ...

# %%
cities.merge(meanofcity, right_index=True, left_on="city", how="left")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1724/4131000315.py in <module>
# ----> 1 cities.merge(meanofcity, right_index=True, left_on="city", how="left")
#
# NameError: name 'cities' is not defined
