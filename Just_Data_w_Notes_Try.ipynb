# %% [markdown]
# # Data Creation

# %% [markdown]
# ### 1. Reading in the Data

# %%
import pandas as pd           #Initialising the needed libaries

# %%
#Data with the Universities
# data = pd.read_csv(r"\Users\jaho3\OneDrive\Documents\group-3\archive\cwurData.csv")#, usecols = ['world_rank',"institution","country", "national_rank", "quality_of_education", "quality_of_faculty", "year"])   
data = pd.read_csv(r"data/cwurData.csv")

# %%
data["has_u"] = data["institution"].str.contains("u")

# %%
def get_balcony_percentage_by_city(city_entries: pd.Series) -> float:
    vc = city_entries.value_counts(normalize = True)
    if True in vc:
        return vc[True]
    else:
        return 1 - vc[False]

placeholder = data.groupby("country")["has_u"].apply(get_balcony_percentage_by_city)

# %%
data.groupby("country")["has_u"].apply(get_balcony_percentage_by_city).reset_index()
# Out:
#                  country     has_u
# 0              Argentina  0.285714
# 1              Australia  0.448276
# 2                Austria  0.333333
# 3                Belgium  0.500000
# 4                 Brazil  0.333333
# 5               Bulgaria  0.000000
# 6                 Canada  0.277778
# 7                  Chile  0.000000
# 8                  China  0.389222
# 9               Colombia  0.000000
# 10               Croatia  0.000000
# 11                Cyprus  1.000000
# 12        Czech Republic  0.800000
# 13               Denmark  0.333333
# 14                 Egypt  0.250000
# 15               Estonia  1.000000
# 16               Finland  0.200000
# 17                France  0.477064
# 18               Germany  0.478261
# 19                Greece  0.000000
# 20             Hong Kong  0.000000
# 21               Hungary  0.166667
# 22               Iceland  0.000000
# 23                 India  0.806452
# 24                  Iran  0.000000
# 25               Ireland  0.500000
# 26                Israel  0.636364
# 27                 Italy  0.208333
# 28                 Japan  0.339623
# 29               Lebanon  1.000000
# 30             Lithuania  1.000000
# 31              Malaysia  0.333333
# 32                Mexico  1.000000
# 33           Netherlands  0.206897
# 34           New Zealand  0.333333
# 35                Norway  0.000000
# 36                Poland  0.111111
# 37              Portugal  0.000000
# 38           Puerto Rico  1.000000
# 39               Romania  0.666667
# 40                Russia  0.444444
# 41          Saudi Arabia  1.000000
# 42                Serbia  0.000000
# 43             Singapore  0.000000
# 44       Slovak Republic  1.000000
# 45              Slovenia  0.500000
# 46          South Africa  0.200000
# 47           South Korea  0.541667
# 48                 Spain  0.308642
# 49                Sweden  0.500000
# 50           Switzerland  0.692308
# 51                Taiwan  0.543478
# 52              Thailand  0.333333
# 53                Turkey  0.300000
# 54                   USA  0.287958
# 55                Uganda  0.000000
# 56  United Arab Emirates  0.000000
# 57        United Kingdom  0.194444
# 58               Uruguay  1.000000

# %%
#Data with Appartment Info
#appartments = pd.read_csv(r"\Users\jaho3\Downloads\archive (3)\immo_data.csv", usecols = ['regio1','serviceCharge','balcony','telekomUploadSpeed','totalRent', "yearConstructed", "hasKitchen","cellar", "baseRent","livingSpace","petsAllowed", "lift","noRooms", "garden", "regio2", "regio3" ])
appartments = pd.read_csv(r"data/immo_data.csv", usecols = ['regio1','serviceCharge','balcony','telekomUploadSpeed','totalRent', "yearConstructed", "hasKitchen","cellar", "baseRent","livingSpace","petsAllowed", "lift","noRooms", "garden", "regio2", "regio3" ])

# %%
#Data with Population Info
population_data=pd.read_csv("data/Deutschland_Cities.csv")
#population_data=pd.read_csv(r"\Users\jaho3\Downloads\TechLabs\TechLabs\Deutschland_Cities.csv")

# %%
data.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year  \
# 0             1          1          1           NaN        5  100.00  2012
# 1            12          4          4           NaN        1   91.67  2012
# 2             4          2          2           NaN       15   89.50  2012
# 3            16         16         11           NaN       50   86.17  2012
# 4            37         22         22           NaN       18   85.21  2012
#
#    has_u
# 0  False
# 1   True
# 2  False
# 3  False
# 4   True

# %%
appartments.head()
# Out:
#                 regio1  serviceCharge  balcony  telekomUploadSpeed  totalRent  \
# 0  Nordrhein_Westfalen         245.00    False                10.0      840.0
# 1      Rheinland_Pfalz         134.00     True                10.0        NaN
# 2              Sachsen         255.00     True                 2.4     1300.0
# 3              Sachsen          58.15     True                40.0        NaN
# 4               Bremen         138.00     True                 NaN      903.0
#
#    yearConstructed  hasKitchen  cellar  baseRent  livingSpace petsAllowed  \
# 0           1965.0       False    True     595.0        86.00         NaN
# 1           1871.0       False   False     800.0        89.00          no
# 2           2019.0       False    True     965.0        83.80         NaN
# 3           1964.0       False   False     343.0        58.15         NaN
# 4           1950.0       False   False     765.0        84.97         NaN
#
#     lift  noRooms  garden               regio2                      regio3
# 0  False      4.0    True             Dortmund                     Schüren
# 1  False      3.0   False    Rhein_Pfalz_Kreis              Böhl_Iggelheim
# 2   True      3.0   False              Dresden  Äußere_Neustadt_Antonstadt
# 3  False      3.0   False  Mittelsachsen_Kreis                    Freiberg
# 4  False      3.0   False               Bremen           Neu_Schwachhausen

# %%
population_data.head()
# Out:
#         city      lat      lng  country iso2              admin_name  capital  \
# 0     Berlin  52.5167  13.3833  Germany   DE                  Berlin  primary
# 1    Hamburg  53.5500  10.0000  Germany   DE                 Hamburg    admin
# 2     Munich  48.1372  11.5755  Germany   DE                 Bavaria    admin
# 3    Cologne  50.9422   6.9578  Germany   DE  North Rhine-Westphalia      NaN
# 4  Frankfurt  50.1136   8.6797  Germany   DE                   Hesse    minor
#
#    population  population_proper
# 0   3644826.0          3644826.0
# 1   1841179.0          1841179.0
# 2   1471508.0          1471508.0
# 3   1085664.0          1085664.0
# 4    753056.0           753056.0

# %% [markdown]
# ### 2. Preparing the Data

# %% [markdown]
# ##### 2.1. Universities

# %%
#Shrinking the Dataset to just Universities from Germany
data = data[data["country"] == "Germany"]

# %%
#Creating a "city"-column via the city names inside the institution names
regex = "(University of [a-zA-ZüäöÖÄÜ]+)"
data["city"] = data["institution"].str.extract(regex)
data["city"] = data["city"].str.replace("University of ", "")
data.loc[data["city"].str.contains("technology", case = False, na = False), "city"] = pd.NA

# %%
#Problem: There are still NaN Values, but only 30 
data["city"].value_counts(dropna = False)
# Out:
# NaN           30
# Munich         7
# Berlin         6
# Heidelberg     4
# Mannheim       2
# Siegen         2
# Osnabrück      2
# Greifswald     2
# Hohenheim      2
# Lübeck         2
# Jena           2
# Bremen         2
# Bayreuth       2
# Potsdam        2
# Halle          2
# Hanover        2
# Rostock        2
# Konstanz       2
# Dortmund       2
# Augsburg       2
# Regensburg     2
# Marburg        2
# Münster        2
# Bonn           2
# Freiburg       2
# Tübingen       2
# Göttingen      2
# Hamburg        2
# Cologne        2
# Erlangen       2
# Duisburg       2
# Würzburg       2
# Kiel           2
# Mainz          2
# Düsseldorf     2
# Ulm            2
# Stuttgart      2
# Oldenburg      2
# Name: city, dtype: int64

# %%
#So we added the missing Values just manually (Manually because of names like "Dresden University of Technology" or "Justus Liebig University Giessen" which are to different to use the other method )
data.to_excel("data/city.xlsx")

# %% [markdown]
# After manually adding the values, we have renamed the city file into city_complete so that our manuall changes will not be overwritten.

# %%
#Now we just read in the data again with the name uni_cities
uni_cities=pd.read_excel(r"data/city_complete.xlsx")

# %%
uni_cities["city"].value_counts(dropna = False)
# Out:
# Munich            7
# Berlin            6
# Heidelberg        4
# Bremen            3
# Kiel              3
# Mannheim          2
# Halle             2
# Jena              2
# Giessen           2
# Saarbrücken       2
# Dortmund          2
# Konstanz          2
# Rostock           2
# Bielefeld         2
# Hanover           2
# Magdeburg         2
# Potsdam           2
# Osnabrück         2
# Marburg           2
# Braunschweig      2
# Kaiserslautern    2
# Augsburg          2
# Lübeck            2
# Hohenheim         2
# Greifswald        2
# Siegen            2
# Bayreuth          2
# Regensburg        2
# Darmstadt         2
# Bochum            2
# Bonn              2
# Freiburg          2
# Tübingen          2
# Frankfurt         2
# Göttingen         2
# Hamburg           2
# Cologne           2
# Münster           2
# Erlangen          2
# Karlsruhe         2
# Würzburg          2
# Dresden           2
# Mainz             2
# Düsseldorf        2
# Ulm               2
# Hannover          2
# Leipzig           2
# Stuttgart         2
# Duisburg          2
# Oldenburg         2
# Aachen            1
# Chemnitz          1
# Name: city, dtype: int64

# %%
uni_cities.head()
# Out:
#    Unnamed: 0  world_rank                             institution  country  \
# 0          81          82  Ruprecht Karl University of Heidelberg  Germany
# 1          82          83  Ludwig Maximilian University of Munich  Germany
# 2          89          90          Technical University of Munich  Germany
# 3         166          67  Ludwig Maximilian University of Munich  Germany
# 4         178          79  Ruprecht Karl University of Heidelberg  Germany
#
#    national_rank  quality_of_education  quality_of_faculty  year        city
# 0              1                    87                  52  2012  Heidelberg
# 1              2                    90                  90  2012      Munich
# 2              3                    52                 101  2012      Munich
# 3              1                    62                  92  2013      Munich
# 4              2                    73                  55  2013  Heidelberg

# %%
#Just rename the old index column if we maybe need it later to compare something
uni_cities.rename(columns={"Unnamed: 0":"old_index"}, inplace=True)

# %%
#Replace "Munich" with "München" so that all cities are there with their german name 
uni_cities["city"]=uni_cities["city"].str.replace("Munich", "München")

# %%
#Replace "Cologne" with "Köln" so that all cities are there with their german name 
uni_cities["city"]=uni_cities["city"].str.replace("Cologne", "Köln")

# %%
#Replace "Hanover" with "Hannover" so that all cities are there with their german name 
uni_cities["city"]=uni_cities["city"].str.replace("Hanover", "Hannover")

# %%
#Replace "Frankfurt" with "Frankfurt am Main" so that the cities in both sets are matching
uni_cities["city"]=uni_cities["city"].str.replace("Frankfurt", "Frankfurt am Main")

# %%
#Replace "Marburg" with "Marburg Biedenkopf" so that the cities in both sets are matching
uni_cities["city"]=uni_cities["city"].str.replace("Marburg", "Marburg Biedenkopf")

# %%
#Replace "Siegen" with "Siegen Wittgenstein" so that the cities in both sets are matching
uni_cities["city"]=uni_cities["city"].str.replace("Siegen", "Siegen Wittgenstein")

# %%
#Replace "Hohenheim" with "Stuttgart" because the University of Hohenheim is in Stuttgart
uni_cities["city"]=uni_cities["city"].str.replace("Hohenheim", "Stuttgart")

# %%
uni_cities
# Out:
#      old_index  world_rank                             institution  country  \
# 0           81          82  Ruprecht Karl University of Heidelberg  Germany
# 1           82          83  Ludwig Maximilian University of Munich  Germany
# 2           89          90          Technical University of Munich  Germany
# 3          166          67  Ludwig Maximilian University of Munich  Germany
# 4          178          79  Ruprecht Karl University of Heidelberg  Germany
# ..         ...         ...                                     ...      ...
# 110       1992         793                 University of Hohenheim  Germany
# 111       2000         801                 University of Oldenburg  Germany
# 112       2056         857                    University of Siegen  Germany
# 113       2075         876                 University of Osnabrück  Germany
# 114       2101         902                  University of Mannheim  Germany
#
#      national_rank  quality_of_education  quality_of_faculty  year  \
# 0                1                    87                  52  2012
# 1                2                    90                  90  2012
# 2                3                    52                 101  2012
# 3                1                    62                  92  2013
# 4                2                    73                  55  2013
# ..             ...                   ...                 ...   ...
# 110             51                   367                 218  2015
# 111             52                   367                 218  2015
# 112             53                   367                 218  2015
# 113             54                   367                 218  2015
# 114             55                   367                 218  2015
#
#                     city
# 0             Heidelberg
# 1                München
# 2                München
# 3                München
# 4             Heidelberg
# ..                   ...
# 110            Stuttgart
# 111            Oldenburg
# 112  Siegen Wittgenstein
# 113            Osnabrück
# 114             Mannheim
#
# [115 rows x 9 columns]

# %% [markdown]
# ##### 2.2. Appartment Data

# %%
appartments
# Out:
#                      regio1  serviceCharge  balcony  telekomUploadSpeed  \
# 0       Nordrhein_Westfalen         245.00    False                10.0
# 1           Rheinland_Pfalz         134.00     True                10.0
# 2                   Sachsen         255.00     True                 2.4
# 3                   Sachsen          58.15     True                40.0
# 4                    Bremen         138.00     True                 NaN
# ...                     ...            ...      ...                 ...
# 268845               Bayern          90.00     True                10.0
# 268846               Hessen         220.00     True                 NaN
# 268847               Hessen         220.00     True                40.0
# 268848  Nordrhein_Westfalen         175.00     True                 NaN
# 268849               Hessen         315.00     True                 NaN
#
#         totalRent  yearConstructed  hasKitchen  cellar  baseRent  livingSpace  \
# 0           840.0           1965.0       False    True     595.0        86.00
# 1             NaN           1871.0       False   False     800.0        89.00
# 2          1300.0           2019.0       False    True     965.0        83.80
# 3             NaN           1964.0       False   False     343.0        58.15
# 4           903.0           1950.0       False   False     765.0        84.97
# ...           ...              ...         ...     ...       ...          ...
# 268845      910.0           2016.0       False    True     820.0        90.00
# 268846     1150.0           1983.0        True   False     930.0       115.00
# 268847      930.0           1965.0       False    True     650.0        95.00
# 268848     1015.0           2019.0       False    True     840.0        70.00
# 268849        NaN           1972.0        True    True     935.0        77.00
#
#        petsAllowed   lift  noRooms  garden                   regio2  \
# 0              NaN  False      4.0    True                 Dortmund
# 1               no  False      3.0   False        Rhein_Pfalz_Kreis
# 2              NaN   True      3.0   False                  Dresden
# 3              NaN  False      3.0   False      Mittelsachsen_Kreis
# 4              NaN  False      3.0   False                   Bremen
# ...            ...    ...      ...     ...                      ...
# 268845          no  False      3.0   False  Weilheim_Schongau_Kreis
# 268846  negotiable  False      3.5   False         Bergstraße_Kreis
# 268847  negotiable  False      4.0    True   Limburg_Weilburg_Kreis
# 268848          no   True      2.0   False                     Köln
# 268849         NaN   True      3.0   False        Frankfurt_am_Main
#
#                             regio3
# 0                          Schüren
# 1                   Böhl_Iggelheim
# 2       Äußere_Neustadt_Antonstadt
# 3                         Freiberg
# 4                Neu_Schwachhausen
# ...                            ...
# 268845                    Eberfing
# 268846                   Viernheim
# 268847         Limburg_an_der_Lahn
# 268848                   Dellbrück
# 268849                  Sossenheim
#
# [268850 rows x 16 columns]

# %% [markdown]
# To combine the Appartment Data with the University Data we need to adjust the City column (regio2)

# %%
#First problem is that in regio2 words are seperated via "_" and not with an space
appartments["regio2"]=appartments["regio2"].str.replace("_", " ")

# %%
#Next problem is that in regio2 words are seperated via "_" and not with an space
appartments["regio2"]=appartments["regio2"].str.replace("ß", "ss")

# %%
#Next problem is that in regio2 "Halle" is called "Halle Saale"
appartments["regio2"]=appartments["regio2"].str.replace("Halle Saale", "Halle")

# %%
#Next problem is that in regio2 "Freiburg" is called "Freiburg im Breisgau"
appartments["regio2"]=appartments["regio2"].str.replace("Freiburg im Breisgau", "Freiburg")

# %%
#Next problem is that in regio2 some Citys are split into regions so we delete "Kreis" 
appartments["regio2"]=appartments["regio2"].str.replace(" Kreis", "")

# %%
#Next problem is that in regio2 the city Saarbrücken is called "Stadtverband Saarbrücken" 
appartments["regio2"]=appartments["regio2"].str.replace("Stadtverband ", "")

# %%
#The changes have worked
appartments["regio2"].unique()
# Out:
# array(['Dortmund', 'Rhein Pfalz', 'Dresden', 'Mittelsachsen', 'Bremen',
#        'Schleswig Flensburg', 'Emmendingen', 'Gelsenkirchen', 'Chemnitz',
#        'Südliche Weinstrasse', 'Hamm', 'Weimar', 'Main Kinzig',
#        'Duisburg', 'Göttingen', 'Neumünster', 'Stuttgart', 'Leipzig',
#        'München', 'Hamburg', 'Braunschweig', 'Esslingen', 'Magdeburg',
#        'Schwerin', 'Passau', 'Mettmann', 'Vogtlandkreis', 'Gross Gerau',
#        'Sächsische Schweiz Osterzgebirge', 'Görlitz',
#        'Rheinisch Bergischer', 'Essen', 'Meissen', 'Mannheim',
#        'Wesermarsch', 'Hochsauerlandkreis', 'Unna', 'Bautzen', 'Berlin',
#        'Frankfurt am Main', 'Halle', 'Steinburg', 'Aschaffenburg',
#        'Oder Spree', 'Bremerhaven', 'Zwickau', 'Nordsachsen',
#        'Mansfeld Südharz', 'Alzey Worms', 'Giessen', 'Main Taunus',
#        'Wuppertal', 'Viersen', 'Düsseldorf', 'Gera', 'Böblingen',
#        'Würzburg', 'Kitzingen', 'Stendal', 'Nordvorpommern', 'Rhein Erft',
#        'Mülheim an der Ruhr', 'Heilbronn', 'Hersfeld Rotenburg', 'Aachen',
#        'Erzgebirgskreis', 'Baden Baden', 'Tuttlingen', 'Nürnberg',
#        'Heinsberg', 'Remscheid', 'Märkisch Oderland', 'Wiesbaden',
#        'Wetteraukreis', 'Kassel', 'Bielefeld', 'Salzlandkreis', 'Harburg',
#        'Höxter', 'Germersheim', 'Brandenburg an der Havel', 'Aurich',
#        'Herzogtum Lauenburg', 'Karlsruhe', 'Frankenthal Pfalz',
#        'Rheingau Taunus', 'Nordwestmecklenburg', 'Ostvorpommern', 'Emden',
#        'Rems Murr', 'Altmarkkreis Salzwedel', 'Straubing', 'Peine',
#        'Paderborn', 'Düren', 'Fürstenfeldbruck', 'Kiel',
#        'Unstrut Hainich', 'Ludwigslust', 'Flensburg', 'Borken', 'Krefeld',
#        'Lörrach', 'Saalekreis', 'Wesel', 'Recklinghausen', 'Hagen',
#        'Grafschaft Bentheim', 'Goslar', 'Bergstrasse', 'Börde', 'Potsdam',
#        'Kusel', 'Burgenlandkreis', 'Holzminden', 'Bad Doberan',
#        'Biberach', 'Coburg', 'Köln', 'Dessau Rosslau', 'Harz',
#        'Ludwigsburg', 'Herne', 'Bad Dürkheim', 'Wittenberg', 'Fürth',
#        'Eichstätt', 'Bochum', 'Pfaffenhofen an der Ilm', 'Märkischer',
#        'Trier', 'Rhein Sieg', 'Hannover', 'Limburg Weilburg',
#        'Mönchengladbach', 'Bonn', 'Anhalt Bitterfeld', 'Herford',
#        'Neuss Rhein', 'Plauen', 'Soest', 'Erding', 'Dahme Spreewald',
#        'Mainz', 'Kleve', 'Reutlingen', 'Offenbach', 'Segeberg', 'Emsland',
#        'Hochtaunuskreis', 'Schwarzwald Baar', 'Oberbergischer',
#        'Wunsiedel im Fichtelgebirge', 'Hildburghausen', 'Wismar',
#        'Pirmasens', 'Schmalkalden Meiningen', 'Ostalbkreis',
#        'Oldenburg Oldenburg', 'Mayen Koblenz', 'Ennepe Ruhr', 'Uckermark',
#        'Mainz Bingen', 'Erfurt', 'Helmstedt', 'Pinneberg', 'Gütersloh',
#        'Starnberg', 'Siegen Wittgenstein', 'Fulda',
#        'Oberspreewald Lausitz', 'Göppingen', 'Werra Meissner', 'Lüneburg',
#        'Wilhelmshaven', 'Wolfsburg', 'Northeim', 'Rhein Lahn', 'Freising',
#        'Lübeck', 'Minden Lübbecke', 'Rastatt', 'Unterallgäu', 'Eisenach',
#        'Spree Neisse', 'Bad Tölz Wolfratshausen', 'Rendsburg Eckernförde',
#        'Augsburg', 'Neustadt a.d. Aisch Bad Windsheim', 'Oberhavel',
#        'Schwalm Eder', 'Stralsund', 'Prignitz', 'Hoyerswerda',
#        'Straubing Bogen', 'Darmstadt Dieburg', 'Landshut', 'Cochem Zell',
#        'Bad Kreuznach', 'Solingen', 'Heidelberg', 'Hof', 'Neubrandenburg',
#        'Osnabrück', 'Donau Ries', 'Güstrow', 'Plön', 'Koblenz',
#        'Alb Donau', 'Heidenheim', 'Bodenseekreis', 'Teltow Fläming',
#        'Westerwaldkreis', 'Celle', 'Potsdam Mittelmark', 'Hildesheim',
#        'Verden', 'Rhein Neckar', 'Havelland', 'Dachau', 'Rotenburg Wümme',
#        'Ostholstein', 'Pforzheim', 'Suhl', 'Stormarn', 'Eichsfeld',
#        'Darmstadt', 'Regensburg', 'Nordhausen', 'Sonneberg', 'Cottbus',
#        'Forchheim', 'Erlangen', 'Nienburg Weser', 'Waldeck Frankenberg',
#        'Dithmarschen', 'Diepholz', 'Deggendorf', 'Oberhausen',
#        'Neustadt an der Weinstrasse', 'Münster', 'Osterode am Harz',
#        'Freudenstadt', 'Marburg Biedenkopf', 'Stade', 'Birkenfeld',
#        'Cuxhaven', 'Rottal Inn', 'Rügen', 'Gotha', 'Offenbach am Main',
#        'Saarbrücken', 'Kyffhäuserkreis', 'Freiburg', 'Ravensburg',
#        'Hameln Pyrmont', 'Saalfeld Rudolstadt', 'Rostock', 'Saarlouis',
#        'Parchim', 'Schwäbisch Hall', 'Bamberg', 'Weilheim Schongau',
#        'Lippe', 'Müritz', 'Steinfurt', 'Traunstein', 'Ebersberg',
#        'Neuwied', 'Kelheim', 'Weimarer Land', 'Saarpfalz', 'Vechta',
#        'Bitburg Prüm', 'Ahrweiler', 'Greifswald', 'Calw', 'Gifhorn',
#        'Uelzen', 'Altenburger Land', 'Ilm', 'Trier Saarburg', 'Lahn Dill',
#        'Worms', 'Berchtesgadener Land', 'Breisgau Hochschwarzwald',
#        'Oldenburg', 'Barnim', 'Erlangen Höchstadt', 'Main Spessart',
#        'Rosenheim', 'Bottrop', 'Ludwigshafen am Rhein', 'Elbe Elster',
#        'Warendorf', 'Mecklenburg Strelitz', 'Jerichower Land',
#        'Lüchow Dannenberg', 'Greiz', 'Euskirchen', 'Kaiserslautern',
#        'Salzgitter', 'Weissenburg Gunzenhausen', 'Ulm', 'Altötting',
#        'Landsberg am Lech', 'Günzburg', 'Amberg Sulzbach',
#        'Wartburgkreis', 'Neu Ulm', 'Lichtenfels', 'Friesland', 'Tübingen',
#        'Zollernalbkreis', 'Enzkreis', 'Miltenberg', 'Schaumburg',
#        'Waldshut', 'Delmenhorst', 'Bayreuth', 'Jena', 'Sömmerda',
#        'Nordfriesland', 'Leer', 'Dillingen an der Donau',
#        'Nürnberger Land', 'Ostprignitz Ruppin', 'Ingolstadt',
#        'Bad Kissingen', 'Saale Holzland', 'Kaufbeuren', 'Speyer',
#        'Ansbach', 'Ammerland', 'Rottweil', 'Mühldorf am Inn',
#        'Weiden in der Oberpfalz', 'Frankfurt Oder',
#        'Garmisch Partenkirchen', 'Main Tauber', 'Ostallgäu', 'Leverkusen',
#        'Neumarkt in der Oberpfalz', 'Aichach Friedberg', 'Neunkirchen',
#        'Coesfeld', 'Lindau Bodensee', 'Ortenaukreis', 'Rhein Hunsrück',
#        'Osterholz', 'Merzig Wadern', 'Heidekreis', 'Wolfenbüttel',
#        'Dingolfing Landau', 'Südwestpfalz', 'Bernkastel Wittlich',
#        'Schweinfurt', 'Demmin', 'Miesbach', 'Konstanz', 'Tirschenreuth',
#        'Neckar Odenwald', 'Altenkirchen Westerwald',
#        'Soltau Fallingbostel', 'Landau in der Pfalz', 'Uecker Randow',
#        'Zweibrücken', 'Neuburg Schrobenhausen', 'Amberg',
#        'Donnersbergkreis', 'Cloppenburg', 'Hohenlohekreis', 'Roth',
#        'Vulkaneifel', 'Vogelsbergkreis', 'Schwandorf', 'Cham',
#        'Sigmaringen', 'Oberallgäu', 'Regen', 'Memmingen',
#        'Kempten Allgäu', 'Freyung Grafenau', 'Odenwaldkreis', 'Olpe',
#        'Saale Orla', 'Sankt Wendel', 'Kulmbach', 'Schwabach', 'Wittmund',
#        'Hassberge', 'Rhön Grabfeld', 'Kronach', 'Neustadt a.d. Waldnaab'],
#       dtype=object)

# %%
#The Appartments Data is grouped by the city so we can aggregate the rent and so on per City
app_city=appartments.groupby(["regio2"])

# %% [markdown]
# The mean total Rent per City

# %%
#Here we save the grouping of the total Rent by city as "meanofcityRent" and take the mean
meanofcityRent=app_city["totalRent"].mean()
meanofcityRent
# Out:
# regio2
# Aachen                808.837117
# Ahrweiler             811.195740
# Aichach Friedberg    1037.368621
# Alb Donau             894.634437
# Altenburger Land      454.977522
#                         ...
# Wuppertal             654.873826
# Würzburg              906.299109
# Zollernalbkreis       823.415200
# Zweibrücken           605.617021
# Zwickau               482.296626
# Name: totalRent, Length: 394, dtype: float64

# %%
#We merge the menofcityRent to the uni_cities DataFrame as new column
uni_cities=uni_cities.merge(meanofcityRent, right_index=True, left_on="city", how="left")

# %%
uni_cities
# Out:
#      old_index  world_rank                             institution  country  \
# 0           81          82  Ruprecht Karl University of Heidelberg  Germany
# 1           82          83  Ludwig Maximilian University of Munich  Germany
# 2           89          90          Technical University of Munich  Germany
# 3          166          67  Ludwig Maximilian University of Munich  Germany
# 4          178          79  Ruprecht Karl University of Heidelberg  Germany
# ..         ...         ...                                     ...      ...
# 110       1992         793                 University of Hohenheim  Germany
# 111       2000         801                 University of Oldenburg  Germany
# 112       2056         857                    University of Siegen  Germany
# 113       2075         876                 University of Osnabrück  Germany
# 114       2101         902                  University of Mannheim  Germany
#
#      national_rank  quality_of_education  quality_of_faculty  year  \
# 0                1                    87                  52  2012
# 1                2                    90                  90  2012
# 2                3                    52                 101  2012
# 3                1                    62                  92  2013
# 4                2                    73                  55  2013
# ..             ...                   ...                 ...   ...
# 110             51                   367                 218  2015
# 111             52                   367                 218  2015
# 112             53                   367                 218  2015
# 113             54                   367                 218  2015
# 114             55                   367                 218  2015
#
#                     city    totalRent
# 0             Heidelberg  1348.422541
# 1                München  1904.166454
# 2                München  1904.166454
# 3                München  1904.166454
# 4             Heidelberg  1348.422541
# ..                   ...          ...
# 110            Stuttgart  1487.458776
# 111            Oldenburg   759.706757
# 112  Siegen Wittgenstein   702.158013
# 113            Osnabrück   796.577535
# 114             Mannheim  1065.804221
#
# [115 rows x 10 columns]

# %% [markdown]
# The median of totalRent per city

# %%
#Here we save the grouping of the total Rent by city as "medianoftotalRent" and take the median
medianoftotalRent=app_city["totalRent"].median()
medianoftotalRent
# Out:
# regio2
# Aachen               735.0
# Ahrweiler            760.0
# Aichach Friedberg    985.0
# Alb Donau            895.0
# Altenburger Land     430.0
#                      ...
# Wuppertal            585.0
# Würzburg             870.0
# Zollernalbkreis      800.0
# Zweibrücken          550.0
# Zwickau              440.0
# Name: totalRent, Length: 394, dtype: float64

# %%
#We merge the medianoftotalRent to the uni_cities DataFrame as new column
uni_cities=uni_cities.merge(medianoftotalRent, right_index=True, left_on="city", how="left")

# %% [markdown]
# Mean of serviceCharge per city

# %%
meanofserviceCharge=app_city["serviceCharge"].mean()
meanofserviceCharge
# Out:
# regio2
# Aachen               159.659296
# Ahrweiler            164.033762
# Aichach Friedberg    163.269231
# Alb Donau            160.179000
# Altenburger Land     113.986117
#                         ...
# Wuppertal            141.145691
# Würzburg             128.759734
# Zollernalbkreis      171.581560
# Zweibrücken          141.250000
# Zwickau              130.361212
# Name: serviceCharge, Length: 394, dtype: float64

# %%
uni_cities=uni_cities.merge(meanofserviceCharge, right_index=True, left_on="city", how="left")

# %% [markdown]
# Median of *serviceCharge* per city

# %%
medianofserviceCharge=app_city["serviceCharge"].median()
medianofserviceCharge
# Out:
# regio2
# Aachen               150.0
# Ahrweiler            150.0
# Aichach Friedberg    150.0
# Alb Donau            150.0
# Altenburger Land     110.0
#                      ...
# Wuppertal            125.0
# Würzburg             130.0
# Zollernalbkreis      150.0
# Zweibrücken          135.0
# Zwickau              125.0
# Name: serviceCharge, Length: 394, dtype: float64

# %%
uni_cities=uni_cities.merge(medianofserviceCharge, right_index=True, left_on="city", how="left")

# %% [markdown]
# Percentage of *balcony*

# %%
def get_balcony_percentage_by_city(city_entries: pd.Series) -> float:
    vc = city_entries.value_counts(normalize = True)
    if True in vc:
        return vc[True]
    else:
        return 1 - vc[False]

test3 = app_city["balcony"].apply(get_balcony_percentage_by_city)

# %%
fertig=app_city["balcony"].apply(get_balcony_percentage_by_city).reset_index()

# %%
def get_balcony_percentage_by_city2(city_entries: pd.Series) -> float:
    vc = city_entries.value_counts(normalize = True)
    if True in vc:
        vc = vc.unstack(level=1).fillna(0)
        vc.columns = vc.columns.droplevel(0)
        return vc[True]
    else:
        return 1 - vc[False]

# %%
petsAllowedtest=app_city["petsAllowed"].apply(get_balcony_percentage_by_city2).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2764/1835948332.py in <module>
# ----> 1 petsAllowedtest=app_city["petsAllowed"].apply(get_balcony_percentage_by_city2).reset_index()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in apply(self, func, *args, **kwargs)
#     221     )
#     222     def apply(self, func, *args, **kwargs):
# --> 223         return super().apply(func, *args, **kwargs)
#     224
#     225     @doc(_agg_template, examples=_agg_examples_doc, klass="Series")
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#    1273         with option_context("mode.chained_assignment", None):
#    1274             try:
# -> 1275                 result = self._python_apply_general(f, self._selected_obj)
#    1276             except TypeError:
#    1277                 # gh-20949
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f, data)
#    1307             data after applying f
#    1308         """
# -> 1309         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#    1310
#    1311         return self._wrap_applied_output(
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     839             # group might be modified
#     840             group_axes = group.axes
# --> 841             res = f(group)
#     842             if not _is_indexed_like(res, group_axes, axis):
#     843                 mutated = True
#
# ~\AppData\Local\Temp/ipykernel_2764/2873341803.py in get_balcony_percentage_by_city2(city_entries)
#       6         return vc[True]
#       7     else:
# ----> 8         return 1 - vc[False]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: False

# %%
vc = vc.unstack(level=1).fillna(0)
vc.columns = vc.columns.droplevel(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2764/1298566997.py in <module>
# ----> 1 vc = vc.unstack(level=1).fillna(0)
#       2 vc.columns = vc.columns.droplevel(0)
#
# NameError: name 'vc' is not defined

# %%
petsAllowedtest=app_city["petsAllowed"].value_counts(normalize=True).to_dict()
petsAllowedtest
#app_city(['id', 'group', 'term']).size().unstack(fill_value=0)
# Out:
# {('Aachen', 'no'): 0.5311315646995127,
#  ('Aachen', 'negotiable'): 0.4401732539252842,
#  ('Aachen', 'yes'): 0.028695181375203032,
#  ('Ahrweiler', 'no'): 0.463302752293578,
#  ('Ahrweiler', 'negotiable'): 0.44954128440366975,
#  ('Ahrweiler', 'yes'): 0.0871559633027523,
#  ('Aichach Friedberg', 'no'): 0.5360824742268041,
#  ('Aichach Friedberg', 'negotiable'): 0.41237113402061853,
#  ('Aichach Friedberg', 'yes'): 0.05154639175257732,
#  ('Alb Donau', 'no'): 0.6875,
#  ('Alb Donau', 'negotiable'): 0.28125,
#  ('Alb Donau', 'yes'): 0.03125,
#  ('Altenburger Land', 'negotiable'): 0.6397694524495677,
#  ('Altenburger Land', 'yes'): 0.29971181556195964,
#  ('Altenburger Land', 'no'): 0.06051873198847262,
#  ('Altenkirchen Westerwald', 'no'): 0.5806451612903226,
#  ('Altenkirchen Westerwald', 'negotiable'): 0.3978494623655914,
#  ('Altenkirchen Westerwald', 'yes'): 0.021505376344086023,
#  ('Altmarkkreis Salzwedel', 'no'): 0.4489795918367347,
#  ('Altmarkkreis Salzwedel', 'negotiable'): 0.42857142857142855,
#  ('Altmarkkreis Salzwedel', 'yes'): 0.12244897959183673,
#  ('Altötting', 'no'): 0.5238095238095238,
#  ('Altötting', 'negotiable'): 0.40476190476190477,
#  ('Altötting', 'yes'): 0.07142857142857142,
#  ('Alzey Worms', 'no'): 0.6739130434782609,
#  ('Alzey Worms', 'negotiable'): 0.2826086956521739,
#  ('Alzey Worms', 'yes'): 0.043478260869565216,
#  ('Amberg', 'no'): 0.625,
#  ('Amberg', 'negotiable'): 0.3333333333333333,
#  ('Amberg', 'yes'): 0.041666666666666664,
#  ('Amberg Sulzbach', 'no'): 0.5862068965517241,
#  ('Amberg Sulzbach', 'negotiable'): 0.3793103448275862,
#  ('Amberg Sulzbach', 'yes'): 0.034482758620689655,
#  ('Ammerland', 'no'): 0.5289855072463768,
#  ('Ammerland', 'negotiable'): 0.45652173913043476,
#  ('Ammerland', 'yes'): 0.014492753623188406,
#  ('Anhalt Bitterfeld', 'negotiable'): 0.7891304347826087,
#  ('Anhalt Bitterfeld', 'yes'): 0.13695652173913042,
#  ('Anhalt Bitterfeld', 'no'): 0.07391304347826087,
#  ('Ansbach', 'no'): 0.5043478260869565,
#  ('Ansbach', 'negotiable'): 0.41739130434782606,
#  ('Ansbach', 'yes'): 0.0782608695652174,
#  ('Aschaffenburg', 'no'): 0.6451612903225806,
#  ('Aschaffenburg', 'negotiable'): 0.3027295285359802,
#  ('Aschaffenburg', 'yes'): 0.052109181141439205,
#  ('Augsburg', 'no'): 0.625154130702836,
#  ('Augsburg', 'negotiable'): 0.35511713933415534,
#  ('Augsburg', 'yes'): 0.01972872996300863,
#  ('Aurich', 'negotiable'): 0.4878048780487805,
#  ('Aurich', 'no'): 0.47560975609756095,
#  ('Aurich', 'yes'): 0.036585365853658534,
#  ('Bad Doberan', 'negotiable'): 0.6938775510204082,
#  ('Bad Doberan', 'no'): 0.17346938775510204,
#  ('Bad Doberan', 'yes'): 0.1326530612244898,
#  ('Bad Dürkheim', 'no'): 0.4411764705882353,
#  ('Bad Dürkheim', 'negotiable'): 0.4019607843137255,
#  ('Bad Dürkheim', 'yes'): 0.1568627450980392,
#  ('Bad Kissingen', 'no'): 0.569620253164557,
#  ('Bad Kissingen', 'negotiable'): 0.3924050632911392,
#  ('Bad Kissingen', 'yes'): 0.0379746835443038,
#  ('Bad Kreuznach', 'no'): 0.48344370860927155,
#  ('Bad Kreuznach', 'negotiable'): 0.4768211920529801,
#  ('Bad Kreuznach', 'yes'): 0.039735099337748346,
#  ('Bad Tölz Wolfratshausen', 'no'): 0.632,
#  ('Bad Tölz Wolfratshausen', 'negotiable'): 0.352,
#  ('Bad Tölz Wolfratshausen', 'yes'): 0.016,
#  ('Baden Baden', 'no'): 0.5,
#  ('Baden Baden', 'negotiable'): 0.4533333333333333,
#  ('Baden Baden', 'yes'): 0.04666666666666667,
#  ('Bamberg', 'no'): 0.6413793103448275,
#  ('Bamberg', 'negotiable'): 0.2827586206896552,
#  ('Bamberg', 'yes'): 0.07586206896551724,
#  ('Barnim', 'negotiable'): 0.774390243902439,
#  ('Barnim', 'no'): 0.18292682926829268,
#  ('Barnim', 'yes'): 0.042682926829268296,
#  ('Bautzen', 'negotiable'): 0.8066860465116279,
#  ('Bautzen', 'no'): 0.1308139534883721,
#  ('Bautzen', 'yes'): 0.0625,
#  ('Bayreuth', 'no'): 0.5797101449275363,
#  ('Bayreuth', 'negotiable'): 0.3961352657004831,
#  ('Bayreuth', 'yes'): 0.024154589371980676,
#  ('Berchtesgadener Land', 'no'): 0.5238095238095238,
#  ('Berchtesgadener Land', 'negotiable'): 0.30952380952380953,
#  ('Berchtesgadener Land', 'yes'): 0.16666666666666666,
#  ('Bergstrasse', 'no'): 0.5666666666666667,
#  ('Bergstrasse', 'negotiable'): 0.4,
#  ('Bergstrasse', 'yes'): 0.03333333333333333,
#  ('Berlin', 'negotiable'): 0.7232399425287356,
#  ('Berlin', 'no'): 0.22431752873563218,
#  ('Berlin', 'yes'): 0.05244252873563218,
#  ('Bernkastel Wittlich', 'no'): 0.5161290322580645,
#  ('Bernkastel Wittlich', 'negotiable'): 0.41935483870967744,
#  ('Bernkastel Wittlich', 'yes'): 0.06451612903225806,
#  ('Biberach', 'no'): 0.8142857142857143,
#  ('Biberach', 'negotiable'): 0.15,
#  ('Biberach', 'yes'): 0.03571428571428571,
#  ('Bielefeld', 'no'): 0.6461538461538462,
#  ('Bielefeld', 'negotiable'): 0.31076923076923074,
#  ('Bielefeld', 'yes'): 0.043076923076923075,
#  ('Birkenfeld', 'negotiable'): 0.6857142857142857,
#  ('Birkenfeld', 'no'): 0.24285714285714285,
#  ('Birkenfeld', 'yes'): 0.07142857142857142,
#  ('Bitburg Prüm', 'negotiable'): 0.525,
#  ('Bitburg Prüm', 'no'): 0.35,
#  ('Bitburg Prüm', 'yes'): 0.125,
#  ('Bochum', 'negotiable'): 0.6023278370514064,
#  ('Bochum', 'no'): 0.3433559650824442,
#  ('Bochum', 'yes'): 0.05431619786614937,
#  ('Bodenseekreis', 'no'): 0.6753246753246753,
#  ('Bodenseekreis', 'negotiable'): 0.2857142857142857,
#  ('Bodenseekreis', 'yes'): 0.03896103896103896,
#  ('Bonn', 'no'): 0.5473815461346634,
#  ('Bonn', 'negotiable'): 0.39775561097256856,
#  ('Bonn', 'yes'): 0.05486284289276808,
#  ('Borken', 'no'): 0.553030303030303,
#  ('Borken', 'negotiable'): 0.3977272727272727,
#  ('Borken', 'yes'): 0.04924242424242424,
#  ('Bottrop', 'negotiable'): 0.7055214723926381,
#  ('Bottrop', 'no'): 0.25766871165644173,
#  ('Bottrop', 'yes'): 0.03680981595092025,
#  ('Brandenburg an der Havel', 'negotiable'): 0.45864661654135336,
#  ('Brandenburg an der Havel', 'yes'): 0.4323308270676692,
#  ('Brandenburg an der Havel', 'no'): 0.10902255639097744,
#  ('Braunschweig', 'no'): 0.47448015122873344,
#  ('Braunschweig', 'negotiable'): 0.45368620037807184,
#  ('Braunschweig', 'yes'): 0.07183364839319471,
#  ('Breisgau Hochschwarzwald', 'no'): 0.7046632124352331,
#  ('Breisgau Hochschwarzwald', 'negotiable'): 0.26424870466321243,
#  ('Breisgau Hochschwarzwald', 'yes'): 0.031088082901554404,
#  ('Bremen', 'negotiable'): 0.5726915520628684,
#  ('Bremen', 'no'): 0.3889980353634578,
#  ('Bremen', 'yes'): 0.03831041257367387,
#  ('Bremerhaven', 'negotiable'): 0.7864406779661017,
#  ('Bremerhaven', 'no'): 0.16779661016949152,
#  ('Bremerhaven', 'yes'): 0.04576271186440678,
#  ('Burgenlandkreis', 'negotiable'): 0.7844940867279895,
#  ('Burgenlandkreis', 'yes'): 0.13797634691195795,
#  ('Burgenlandkreis', 'no'): 0.07752956636005257,
#  ('Böblingen', 'no'): 0.665903890160183,
#  ('Böblingen', 'negotiable'): 0.2951945080091533,
#  ('Böblingen', 'yes'): 0.038901601830663615,
#  ('Börde', 'negotiable'): 0.8597449908925319,
#  ('Börde', 'no'): 0.08378870673952642,
#  ('Börde', 'yes'): 0.056466302367941715,
#  ('Calw', 'no'): 0.5797872340425532,
#  ('Calw', 'negotiable'): 0.35638297872340424,
#  ('Calw', 'yes'): 0.06382978723404255,
#  ('Celle', 'negotiable'): 0.49079754601226994,
#  ('Celle', 'no'): 0.4662576687116564,
#  ('Celle', 'yes'): 0.04294478527607362,
#  ('Cham', 'negotiable'): 0.532258064516129,
#  ('Cham', 'no'): 0.3548387096774194,
#  ('Cham', 'yes'): 0.11290322580645161,
#  ('Chemnitz', 'negotiable'): 0.8996627318718381,
#  ('Chemnitz', 'yes'): 0.07407853529270056,
#  ('Chemnitz', 'no'): 0.026258732835461335,
#  ('Cloppenburg', 'negotiable'): 0.5483870967741935,
#  ('Cloppenburg', 'no'): 0.45161290322580644,
#  ('Coburg', 'no'): 0.5703703703703704,
#  ('Coburg', 'negotiable'): 0.3851851851851852,
#  ('Coburg', 'yes'): 0.044444444444444446,
#  ('Cochem Zell', 'negotiable'): 0.5641025641025641,
#  ('Cochem Zell', 'no'): 0.38461538461538464,
#  ('Cochem Zell', 'yes'): 0.05128205128205128,
#  ('Coesfeld', 'no'): 0.6114649681528662,
#  ('Coesfeld', 'negotiable'): 0.3503184713375796,
#  ('Coesfeld', 'yes'): 0.03821656050955414,
#  ('Cottbus', 'negotiable'): 0.8185053380782918,
#  ('Cottbus', 'no'): 0.10320284697508897,
#  ('Cottbus', 'yes'): 0.07829181494661921,
#  ('Cuxhaven', 'negotiable'): 0.5446428571428571,
#  ('Cuxhaven', 'no'): 0.36607142857142855,
#  ('Cuxhaven', 'yes'): 0.08928571428571429,
#  ('Dachau', 'no'): 0.6602564102564102,
#  ('Dachau', 'negotiable'): 0.28846153846153844,
#  ('Dachau', 'yes'): 0.05128205128205128,
#  ('Dahme Spreewald', 'negotiable'): 0.8157894736842105,
#  ('Dahme Spreewald', 'no'): 0.11654135338345864,
#  ('Dahme Spreewald', 'yes'): 0.06766917293233082,
#  ('Darmstadt', 'no'): 0.5407166123778502,
#  ('Darmstadt', 'negotiable'): 0.4201954397394137,
#  ('Darmstadt', 'yes'): 0.03908794788273615,
#  ('Darmstadt Dieburg', 'no'): 0.5924855491329479,
#  ('Darmstadt Dieburg', 'negotiable'): 0.36127167630057805,
#  ('Darmstadt Dieburg', 'yes'): 0.046242774566473986,
#  ('Deggendorf', 'no'): 0.5700934579439252,
#  ('Deggendorf', 'negotiable'): 0.40186915887850466,
#  ('Deggendorf', 'yes'): 0.028037383177570093,
#  ('Delmenhorst', 'negotiable'): 0.5463917525773195,
#  ('Delmenhorst', 'no'): 0.41237113402061853,
#  ('Delmenhorst', 'yes'): 0.041237113402061855,
#  ('Demmin', 'negotiable'): 0.813953488372093,
#  ('Demmin', 'no'): 0.09302325581395349,
#  ('Demmin', 'yes'): 0.09302325581395349,
#  ('Dessau Rosslau', 'negotiable'): 0.8394495412844036,
#  ('Dessau Rosslau', 'no'): 0.08409785932721713,
#  ('Dessau Rosslau', 'yes'): 0.0764525993883792,
#  ('Diepholz', 'no'): 0.46923076923076923,
#  ('Diepholz', 'negotiable'): 0.43846153846153846,
#  ('Diepholz', 'yes'): 0.09230769230769231,
#  ('Dillingen an der Donau', 'no'): 0.6,
#  ('Dillingen an der Donau', 'negotiable'): 0.35555555555555557,
#  ('Dillingen an der Donau', 'yes'): 0.044444444444444446,
#  ('Dingolfing Landau', 'no'): 0.7777777777777778,
#  ('Dingolfing Landau', 'negotiable'): 0.2222222222222222,
#  ('Dithmarschen', 'negotiable'): 0.6486486486486487,
#  ('Dithmarschen', 'no'): 0.33783783783783783,
#  ('Dithmarschen', 'yes'): 0.013513513513513514,
#  ('Donau Ries', 'no'): 0.6,
#  ('Donau Ries', 'negotiable'): 0.32727272727272727,
#  ('Donau Ries', 'yes'): 0.07272727272727272,
#  ('Donnersbergkreis', 'no'): 0.46,
#  ('Donnersbergkreis', 'negotiable'): 0.42,
#  ('Donnersbergkreis', 'yes'): 0.12,
#  ('Dortmund', 'negotiable'): 0.5794078061911171,
#  ('Dortmund', 'no'): 0.35868102288021536,
#  ('Dortmund', 'yes'): 0.06191117092866756,
#  ('Dresden', 'negotiable'): 0.7023933402705516,
#  ('Dresden', 'no'): 0.20638224072147068,
#  ('Dresden', 'yes'): 0.0912244190079778,
#  ('Duisburg', 'negotiable'): 0.7589055240061952,
#  ('Duisburg', 'no'): 0.17191533298915848,
#  ('Duisburg', 'yes'): 0.06917914300464637,
#  ('Düren', 'no'): 0.5352112676056338,
#  ('Düren', 'negotiable'): 0.428169014084507,
#  ('Düren', 'yes'): 0.036619718309859155,
#  ('Düsseldorf', 'negotiable'): 0.5588768115942029,
#  ('Düsseldorf', 'no'): 0.40307971014492755,
#  ('Düsseldorf', 'yes'): 0.03804347826086957,
#  ('Ebersberg', 'no'): 0.6728395061728395,
#  ('Ebersberg', 'negotiable'): 0.2716049382716049,
#  ('Ebersberg', 'yes'): 0.05555555555555555,
#  ('Eichsfeld', 'negotiable'): 0.5230769230769231,
#  ('Eichsfeld', 'no'): 0.4461538461538462,
#  ('Eichsfeld', 'yes'): 0.03076923076923077,
#  ('Eichstätt', 'no'): 0.6218487394957983,
#  ('Eichstätt', 'negotiable'): 0.33613445378151263,
#  ('Eichstätt', 'yes'): 0.04201680672268908,
#  ('Eisenach', 'negotiable'): 0.7965367965367965,
#  ('Eisenach', 'no'): 0.1645021645021645,
#  ('Eisenach', 'yes'): 0.03896103896103896,
#  ('Elbe Elster', 'negotiable'): 0.568,
#  ('Elbe Elster', 'no'): 0.272,
#  ('Elbe Elster', 'yes'): 0.16,
#  ('Emden', 'negotiable'): 0.6842105263157895,
#  ('Emden', 'no'): 0.2631578947368421,
#  ('Emden', 'yes'): 0.05263157894736842,
#  ('Emmendingen', 'no'): 0.7413793103448276,
#  ('Emmendingen', 'negotiable'): 0.22413793103448276,
#  ('Emmendingen', 'yes'): 0.034482758620689655,
#  ('Emsland', 'no'): 0.594059405940594,
#  ('Emsland', 'negotiable'): 0.38613861386138615,
#  ('Emsland', 'yes'): 0.019801980198019802,
#  ('Ennepe Ruhr', 'negotiable'): 0.7043073341094296,
#  ('Ennepe Ruhr', 'no'): 0.23632130384167638,
#  ('Ennepe Ruhr', 'yes'): 0.059371362048894066,
#  ('Enzkreis', 'no'): 0.6666666666666666,
#  ('Enzkreis', 'negotiable'): 0.3170731707317073,
#  ('Enzkreis', 'yes'): 0.016260162601626018,
#  ('Erding', 'no'): 0.7041420118343196,
#  ('Erding', 'negotiable'): 0.25443786982248523,
#  ('Erding', 'yes'): 0.04142011834319527,
#  ('Erfurt', 'negotiable'): 0.6580645161290323,
#  ('Erfurt', 'no'): 0.24301075268817204,
#  ('Erfurt', 'yes'): 0.0989247311827957,
#  ('Erlangen', 'no'): 0.6666666666666666,
#  ('Erlangen', 'negotiable'): 0.21693121693121692,
#  ('Erlangen', 'yes'): 0.1164021164021164,
#  ('Erlangen Höchstadt', 'no'): 0.6946564885496184,
#  ('Erlangen Höchstadt', 'negotiable'): 0.3053435114503817,
#  ('Erzgebirgskreis', 'negotiable'): 0.8734729493891797,
#  ('Erzgebirgskreis', 'no'): 0.07417102966841187,
#  ('Erzgebirgskreis', 'yes'): 0.05235602094240838,
#  ('Essen', 'negotiable'): 0.666073018699911,
#  ('Essen', 'no'): 0.27560106856634015,
#  ('Essen', 'yes'): 0.05832591273374889,
#  ('Esslingen', 'no'): 0.7156862745098039,
#  ('Esslingen', 'negotiable'): 0.24509803921568626,
#  ('Esslingen', 'yes'): 0.0392156862745098,
#  ('Euskirchen', 'no'): 0.5695067264573991,
#  ('Euskirchen', 'negotiable'): 0.3901345291479821,
#  ('Euskirchen', 'yes'): 0.04035874439461883,
#  ('Flensburg', 'negotiable'): 0.6085858585858586,
#  ('Flensburg', 'no'): 0.3560606060606061,
#  ('Flensburg', 'yes'): 0.03535353535353535,
#  ('Forchheim', 'no'): 0.6103896103896104,
#  ('Forchheim', 'negotiable'): 0.3246753246753247,
#  ('Forchheim', 'yes'): 0.06493506493506493,
#  ('Frankenthal Pfalz', 'negotiable'): 0.5076923076923077,
#  ('Frankenthal Pfalz', 'no'): 0.49230769230769234,
#  ('Frankfurt Oder', 'negotiable'): 0.8352941176470589,
#  ('Frankfurt Oder', 'yes'): 0.1,
#  ('Frankfurt Oder', 'no'): 0.06470588235294118,
#  ('Frankfurt am Main', 'no'): 0.505669886602268,
#  ('Frankfurt am Main', 'negotiable'): 0.4388912221755565,
#  ('Frankfurt am Main', 'yes'): 0.05543889122217556,
#  ('Freiburg', 'no'): 0.6560509554140127,
#  ('Freiburg', 'negotiable'): 0.2802547770700637,
#  ('Freiburg', 'yes'): 0.06369426751592357,
#  ('Freising', 'no'): 0.7445887445887446,
#  ('Freising', 'negotiable'): 0.23376623376623376,
#  ('Freising', 'yes'): 0.021645021645021644,
#  ('Freudenstadt', 'no'): 0.610738255033557,
#  ('Freudenstadt', 'negotiable'): 0.348993288590604,
#  ('Freudenstadt', 'yes'): 0.040268456375838924,
#  ('Freyung Grafenau', 'negotiable'): 0.5384615384615384,
#  ('Freyung Grafenau', 'no'): 0.3076923076923077,
#  ('Freyung Grafenau', 'yes'): 0.15384615384615385,
#  ('Friesland', 'negotiable'): 0.5384615384615384,
#  ('Friesland', 'no'): 0.4307692307692308,
#  ('Friesland', 'yes'): 0.03076923076923077,
#  ('Fulda', 'no'): 0.7149532710280374,
#  ('Fulda', 'negotiable'): 0.2383177570093458,
#  ('Fulda', 'yes'): 0.04672897196261682,
#  ('Fürstenfeldbruck', 'no'): 0.574585635359116,
#  ('Fürstenfeldbruck', 'negotiable'): 0.3867403314917127,
#  ('Fürstenfeldbruck', 'yes'): 0.03867403314917127,
#  ('Fürth', 'no'): 0.5897435897435898,
#  ('Fürth', 'negotiable'): 0.3141025641025641,
#  ('Fürth', 'yes'): 0.09615384615384616,
#  ('Garmisch Partenkirchen', 'no'): 0.5192307692307693,
#  ('Garmisch Partenkirchen', 'negotiable'): 0.38461538461538464,
#  ('Garmisch Partenkirchen', 'yes'): 0.09615384615384616,
#  ('Gelsenkirchen', 'negotiable'): 0.7267156862745098,
#  ('Gelsenkirchen', 'no'): 0.1636029411764706,
#  ('Gelsenkirchen', 'yes'): 0.1096813725490196,
#  ('Gera', 'negotiable'): 0.8040712468193384,
#  ('Gera', 'yes'): 0.1297709923664122,
#  ('Gera', 'no'): 0.06615776081424936,
#  ('Germersheim', 'no'): 0.782608695652174,
#  ('Germersheim', 'negotiable'): 0.18115942028985507,
#  ('Germersheim', 'yes'): 0.036231884057971016,
#  ('Giessen', 'no'): 0.5631313131313131,
#  ('Giessen', 'negotiable'): 0.4116161616161616,
#  ('Giessen', 'yes'): 0.025252525252525252,
#  ('Gifhorn', 'negotiable'): 0.5527950310559007,
#  ('Gifhorn', 'no'): 0.4161490683229814,
#  ('Gifhorn', 'yes'): 0.031055900621118012,
#  ('Goslar', 'negotiable'): 0.6938325991189427,
#  ('Goslar', 'no'): 0.22687224669603523,
#  ('Goslar', 'yes'): 0.07929515418502203,
#  ('Gotha', 'negotiable'): 0.7383512544802867,
#  ('Gotha', 'no'): 0.23297491039426524,
#  ('Gotha', 'yes'): 0.02867383512544803,
#  ('Grafschaft Bentheim', 'no'): 0.625,
#  ('Grafschaft Bentheim', 'negotiable'): 0.375,
#  ('Greifswald', 'negotiable'): 0.552,
#  ('Greifswald', 'no'): 0.384,
#  ('Greifswald', 'yes'): 0.064,
#  ('Greiz', 'negotiable'): 0.8533333333333334,
#  ('Greiz', 'no'): 0.08,
#  ('Greiz', 'yes'): 0.06666666666666667,
#  ('Gross Gerau', 'no'): 0.6111111111111112,
#  ('Gross Gerau', 'negotiable'): 0.36666666666666664,
#  ('Gross Gerau', 'yes'): 0.022222222222222223,
#  ('Göppingen', 'no'): 0.7150259067357513,
#  ('Göppingen', 'negotiable'): 0.25906735751295334,
#  ('Göppingen', 'yes'): 0.025906735751295335,
#  ('Görlitz', 'negotiable'): 0.8169456066945606,
#  ('Görlitz', 'yes'): 0.11610878661087866,
#  ('Görlitz', 'no'): 0.06694560669456066,
#  ('Göttingen', 'no'): 0.6141552511415526,
#  ('Göttingen', 'negotiable'): 0.3424657534246575,
#  ('Göttingen', 'yes'): 0.04337899543378995,
#  ('Günzburg', 'no'): 0.75,
#  ('Günzburg', 'negotiable'): 0.25,
#  ('Güstrow', 'negotiable'): 0.7925925925925926,
#  ('Güstrow', 'no'): 0.1037037037037037,
#  ('Güstrow', 'yes'): 0.1037037037037037,
#  ('Gütersloh', 'no'): 0.7236467236467237,
#  ('Gütersloh', 'negotiable'): 0.2706552706552707,
#  ('Gütersloh', 'yes'): 0.005698005698005698,
#  ('Hagen', 'negotiable'): 0.8,
#  ('Hagen', 'no'): 0.15263157894736842,
#  ('Hagen', 'yes'): 0.04736842105263158,
#  ('Halle', 'negotiable'): 0.7518691588785047,
#  ('Halle', 'yes'): 0.19345794392523363,
#  ('Halle', 'no'): 0.054672897196261686,
#  ('Hamburg', 'negotiable'): 0.49489795918367346,
#  ('Hamburg', 'no'): 0.4308390022675737,
#  ('Hamburg', 'yes'): 0.07426303854875284,
#  ('Hameln Pyrmont', 'negotiable'): 0.748792270531401,
#  ('Hameln Pyrmont', 'no'): 0.1932367149758454,
#  ('Hameln Pyrmont', 'yes'): 0.057971014492753624,
#  ('Hamm', 'negotiable'): 0.627906976744186,
#  ('Hamm', 'no'): 0.3178294573643411,
#  ('Hamm', 'yes'): 0.05426356589147287,
#  ('Hannover', 'no'): 0.48092967818831944,
#  ('Hannover', 'negotiable'): 0.4719904648390942,
#  ('Hannover', 'yes'): 0.04707985697258641,
#  ('Harburg', 'negotiable'): 0.5277777777777778,
#  ('Harburg', 'no'): 0.4305555555555556,
#  ('Harburg', 'yes'): 0.041666666666666664,
#  ('Harz', 'negotiable'): 0.7837837837837838,
#  ('Harz', 'no'): 0.15405405405405406,
#  ('Harz', 'yes'): 0.062162162162162166,
#  ('Hassberge', 'negotiable'): 0.4444444444444444,
#  ('Hassberge', 'no'): 0.3333333333333333,
#  ('Hassberge', 'yes'): 0.2222222222222222,
#  ('Havelland', 'negotiable'): 0.783068783068783,
#  ('Havelland', 'no'): 0.1746031746031746,
#  ('Havelland', 'yes'): 0.042328042328042326,
#  ('Heidekreis', 'no'): 0.47586206896551725,
#  ('Heidekreis', 'negotiable'): 0.36551724137931035,
#  ('Heidekreis', 'yes'): 0.15862068965517243,
#  ('Heidelberg', 'no'): 0.6355140186915887,
#  ('Heidelberg', 'negotiable'): 0.3302180685358255,
#  ('Heidelberg', 'yes'): 0.03426791277258567,
#  ('Heidenheim', 'no'): 0.671875,
#  ('Heidenheim', 'negotiable'): 0.28125,
#  ('Heidenheim', 'yes'): 0.046875,
#  ('Heilbronn', 'no'): 0.7304747320061256,
#  ('Heilbronn', 'negotiable'): 0.23736600306278713,
#  ('Heilbronn', 'yes'): 0.03215926493108729,
#  ('Heinsberg', 'no'): 0.5012722646310432,
#  ('Heinsberg', 'negotiable'): 0.4732824427480916,
#  ('Heinsberg', 'yes'): 0.02544529262086514,
#  ('Helmstedt', 'negotiable'): 0.7537878787878788,
#  ('Helmstedt', 'no'): 0.14393939393939395,
#  ('Helmstedt', 'yes'): 0.10227272727272728,
#  ('Herford', 'no'): 0.5145228215767634,
#  ('Herford', 'negotiable'): 0.45643153526970953,
#  ('Herford', 'yes'): 0.029045643153526972,
#  ('Herne', 'negotiable'): 0.72782874617737,
#  ('Herne', 'no'): 0.20336391437308868,
#  ('Herne', 'yes'): 0.06880733944954129,
#  ('Hersfeld Rotenburg', 'negotiable'): 0.616822429906542,
#  ('Hersfeld Rotenburg', 'no'): 0.35514018691588783,
#  ('Hersfeld Rotenburg', 'yes'): 0.028037383177570093,
#  ('Herzogtum Lauenburg', 'negotiable'): 0.7040358744394619,
#  ('Herzogtum Lauenburg', 'no'): 0.242152466367713,
#  ('Herzogtum Lauenburg', 'yes'): 0.053811659192825115,
#  ('Hildburghausen', 'negotiable'): 0.8857142857142857,
#  ('Hildburghausen', 'no'): 0.11428571428571428,
#  ('Hildesheim', 'negotiable'): 0.5043478260869565,
#  ('Hildesheim', 'no'): 0.4608695652173913,
#  ('Hildesheim', 'yes'): 0.034782608695652174,
#  ('Hochsauerlandkreis', 'no'): 0.5169491525423728,
#  ('Hochsauerlandkreis', 'negotiable'): 0.3813559322033898,
#  ('Hochsauerlandkreis', 'yes'): 0.1016949152542373,
#  ('Hochtaunuskreis', 'negotiable'): 0.4846743295019157,
#  ('Hochtaunuskreis', 'no'): 0.4425287356321839,
#  ('Hochtaunuskreis', 'yes'): 0.07279693486590039,
#  ('Hof', 'negotiable'): 0.6363636363636364,
#  ('Hof', 'no'): 0.3051948051948052,
#  ('Hof', 'yes'): 0.05844155844155844,
#  ('Hohenlohekreis', 'no'): 0.8072289156626506,
#  ('Hohenlohekreis', 'negotiable'): 0.14457831325301204,
#  ('Hohenlohekreis', 'yes'): 0.04819277108433735,
#  ('Holzminden', 'negotiable'): 0.6458333333333334,
#  ('Holzminden', 'no'): 0.2760416666666667,
#  ('Holzminden', 'yes'): 0.078125,
#  ('Hoyerswerda', 'negotiable'): 0.9615384615384616,
#  ('Hoyerswerda', 'no'): 0.038461538461538464,
#  ('Höxter', 'negotiable'): 0.6,
#  ('Höxter', 'no'): 0.38181818181818183,
#  ('Höxter', 'yes'): 0.01818181818181818,
#  ('Ilm', 'negotiable'): 0.6050420168067226,
#  ('Ilm', 'no'): 0.2689075630252101,
#  ('Ilm', 'yes'): 0.12605042016806722,
#  ('Ingolstadt', 'no'): 0.6907514450867052,
#  ('Ingolstadt', 'negotiable'): 0.28034682080924855,
#  ('Ingolstadt', 'yes'): 0.028901734104046242,
#  ('Jena', 'negotiable'): 0.589041095890411,
#  ('Jena', 'no'): 0.3835616438356164,
#  ('Jena', 'yes'): 0.0273972602739726,
#  ('Jerichower Land', 'negotiable'): 0.7821782178217822,
#  ('Jerichower Land', 'no'): 0.12871287128712872,
#  ('Jerichower Land', 'yes'): 0.0891089108910891,
#  ('Kaiserslautern', 'no'): 0.48717948717948717,
#  ('Kaiserslautern', 'negotiable'): 0.46153846153846156,
#  ('Kaiserslautern', 'yes'): 0.05128205128205128,
#  ('Karlsruhe', 'no'): 0.69901547116737,
#  ('Karlsruhe', 'negotiable'): 0.2812939521800281,
#  ('Karlsruhe', 'yes'): 0.01969057665260197,
#  ('Kassel', 'negotiable'): 0.5311203319502075,
#  ('Kassel', 'no'): 0.4149377593360996,
#  ('Kassel', 'yes'): 0.05394190871369295,
#  ('Kaufbeuren', 'no'): 0.6333333333333333,
#  ('Kaufbeuren', 'negotiable'): 0.36666666666666664,
#  ('Kelheim', 'no'): 0.7596153846153846,
#  ('Kelheim', 'negotiable'): 0.22115384615384615,
#  ('Kelheim', 'yes'): 0.019230769230769232,
#  ('Kempten Allgäu', 'no'): 0.6976744186046512,
#  ('Kempten Allgäu', 'negotiable'): 0.27906976744186046,
#  ('Kempten Allgäu', 'yes'): 0.023255813953488372,
#  ('Kiel', 'negotiable'): 0.5853018372703412,
#  ('Kiel', 'no'): 0.3937007874015748,
#  ('Kiel', 'yes'): 0.02099737532808399,
#  ('Kitzingen', 'no'): 0.7555555555555555,
#  ('Kitzingen', 'negotiable'): 0.24444444444444444,
#  ('Kleve', 'no'): 0.5902439024390244,
#  ('Kleve', 'negotiable'): 0.3878048780487805,
#  ('Kleve', 'yes'): 0.02195121951219512,
#  ('Koblenz', 'no'): 0.5319767441860465,
#  ('Koblenz', 'negotiable'): 0.436046511627907,
#  ('Koblenz', 'yes'): 0.03197674418604651,
#  ('Konstanz', 'no'): 0.639344262295082,
#  ('Konstanz', 'negotiable'): 0.30327868852459017,
#  ('Konstanz', 'yes'): 0.05737704918032787,
#  ('Krefeld', 'negotiable'): 0.6688382193268186,
#  ('Krefeld', 'no'): 0.2888165038002172,
#  ('Krefeld', 'yes'): 0.04234527687296417,
#  ('Kronach', 'negotiable'): 0.5714285714285714,
#  ('Kronach', 'no'): 0.42857142857142855,
#  ('Kulmbach', 'no'): 0.5769230769230769,
#  ('Kulmbach', 'negotiable'): 0.34615384615384615,
#  ('Kulmbach', 'yes'): 0.07692307692307693,
#  ('Kusel', 'negotiable'): 0.6129032258064516,
#  ('Kusel', 'no'): 0.2903225806451613,
#  ('Kusel', 'yes'): 0.0967741935483871,
#  ('Kyffhäuserkreis', 'negotiable'): 0.7586206896551724,
#  ('Kyffhäuserkreis', 'no'): 0.13793103448275862,
#  ('Kyffhäuserkreis', 'yes'): 0.10344827586206896,
#  ('Köln', 'no'): 0.5,
#  ('Köln', 'negotiable'): 0.46454767726161367,
#  ('Köln', 'yes'): 0.035452322738386305,
#  ('Lahn Dill', 'no'): 0.5268817204301075,
#  ('Lahn Dill', 'negotiable'): 0.44086021505376344,
#  ('Lahn Dill', 'yes'): 0.03225806451612903,
#  ('Landau in der Pfalz', 'no'): 0.5964912280701754,
#  ('Landau in der Pfalz', 'negotiable'): 0.40350877192982454,
#  ('Landsberg am Lech', 'no'): 0.6017699115044248,
#  ('Landsberg am Lech', 'negotiable'): 0.34513274336283184,
#  ('Landsberg am Lech', 'yes'): 0.05309734513274336,
#  ('Landshut', 'no'): 0.6606606606606606,
#  ('Landshut', 'negotiable'): 0.32432432432432434,
#  ('Landshut', 'yes'): 0.015015015015015015,
#  ('Leer', 'negotiable'): 0.5257731958762887,
#  ('Leer', 'no'): 0.4329896907216495,
#  ('Leer', 'yes'): 0.041237113402061855,
#  ('Leipzig', 'negotiable'): 0.754932502596054,
#  ('Leipzig', 'yes'): 0.1300103842159917,
#  ('Leipzig', 'no'): 0.11505711318795431,
#  ('Leverkusen', 'no'): 0.5527950310559007,
#  ('Leverkusen', 'negotiable'): 0.391304347826087,
#  ('Leverkusen', 'yes'): 0.055900621118012424,
#  ('Lichtenfels', 'negotiable'): 0.6923076923076923,
#  ('Lichtenfels', 'no'): 0.2692307692307692,
#  ('Lichtenfels', 'yes'): 0.038461538461538464,
#  ('Limburg Weilburg', 'negotiable'): 0.5226480836236934,
#  ('Limburg Weilburg', 'no'): 0.4529616724738676,
#  ('Limburg Weilburg', 'yes'): 0.024390243902439025,
#  ('Lindau Bodensee', 'no'): 0.48148148148148145,
#  ('Lindau Bodensee', 'negotiable'): 0.4691358024691358,
#  ('Lindau Bodensee', 'yes'): 0.04938271604938271,
#  ('Lippe', 'negotiable'): 0.5526992287917738,
#  ('Lippe', 'no'): 0.4087403598971722,
#  ('Lippe', 'yes'): 0.038560411311053984,
#  ('Ludwigsburg', 'no'): 0.7670329670329671,
#  ('Ludwigsburg', 'negotiable'): 0.210989010989011,
#  ('Ludwigsburg', 'yes'): 0.02197802197802198,
#  ('Ludwigshafen am Rhein', 'no'): 0.6363636363636364,
#  ('Ludwigshafen am Rhein', 'negotiable'): 0.3157894736842105,
#  ('Ludwigshafen am Rhein', 'yes'): 0.04784688995215311,
#  ('Ludwigslust', 'negotiable'): 0.634703196347032,
#  ('Ludwigslust', 'yes'): 0.1917808219178082,
#  ('Ludwigslust', 'no'): 0.1735159817351598,
#  ('Lörrach', 'no'): 0.7552674230145867,
#  ('Lörrach', 'negotiable'): 0.17179902755267423,
#  ('Lörrach', 'yes'): 0.07293354943273905,
#  ('Lübeck', 'negotiable'): 0.5948717948717949,
#  ('Lübeck', 'no'): 0.37435897435897436,
#  ('Lübeck', 'yes'): 0.03076923076923077,
#  ('Lüchow Dannenberg', 'negotiable'): 0.8837209302325582,
#  ('Lüchow Dannenberg', 'yes'): 0.09302325581395349,
#  ('Lüchow Dannenberg', 'no'): 0.023255813953488372,
#  ('Lüneburg', 'no'): 0.6405693950177936,
#  ('Lüneburg', 'negotiable'): 0.3416370106761566,
#  ('Lüneburg', 'yes'): 0.017793594306049824,
#  ('Magdeburg', 'negotiable'): 0.8099902056807052,
#  ('Magdeburg', 'no'): 0.11557296767874632,
#  ('Magdeburg', 'yes'): 0.07443682664054849,
#  ('Main Kinzig', 'no'): 0.5014836795252225,
#  ('Main Kinzig', 'negotiable'): 0.4362017804154303,
#  ('Main Kinzig', 'yes'): 0.06231454005934718,
#  ('Main Spessart', 'no'): 0.575,
#  ('Main Spessart', 'negotiable'): 0.375,
#  ('Main Spessart', 'yes'): 0.05,
#  ('Main Tauber', 'no'): 0.7,
#  ('Main Tauber', 'negotiable'): 0.275,
#  ('Main Tauber', 'yes'): 0.025,
#  ('Main Taunus', 'no'): 0.5847299813780261,
#  ('Main Taunus', 'negotiable'): 0.35567970204841715,
#  ('Main Taunus', 'yes'): 0.0595903165735568,
#  ('Mainz', 'no'): 0.6167315175097277,
#  ('Mainz', 'negotiable'): 0.3540856031128405,
#  ('Mainz', 'yes'): 0.029182879377431907,
#  ('Mainz Bingen', 'no'): 0.5541561712846348,
#  ('Mainz Bingen', 'negotiable'): 0.4005037783375315,
#  ('Mainz Bingen', 'yes'): 0.04534005037783375,
#  ('Mannheim', 'no'): 0.6378504672897196,
#  ('Mannheim', 'negotiable'): 0.3399532710280374,
#  ('Mannheim', 'yes'): 0.02219626168224299,
#  ('Mansfeld Südharz', 'negotiable'): 0.8187134502923976,
#  ('Mansfeld Südharz', 'yes'): 0.12085769980506822,
#  ('Mansfeld Südharz', 'no'): 0.06042884990253411,
#  ('Marburg Biedenkopf', 'no'): 0.6070175438596491,
#  ('Marburg Biedenkopf', 'negotiable'): 0.3684210526315789,
#  ('Marburg Biedenkopf', 'yes'): 0.02456140350877193,
#  ('Mayen Koblenz', 'no'): 0.62109375,
#  ('Mayen Koblenz', 'negotiable'): 0.33984375,
#  ('Mayen Koblenz', 'yes'): 0.0390625,
#  ('Mecklenburg Strelitz', 'negotiable'): 0.8906882591093117,
#  ('Mecklenburg Strelitz', 'no'): 0.0728744939271255,
#  ('Mecklenburg Strelitz', 'yes'): 0.03643724696356275,
#  ('Meissen', 'negotiable'): 0.8656126482213439,
#  ('Meissen', 'no'): 0.09090909090909091,
#  ('Meissen', 'yes'): 0.043478260869565216,
#  ('Memmingen', 'no'): 0.6086956521739131,
#  ('Memmingen', 'negotiable'): 0.34782608695652173,
#  ('Memmingen', 'yes'): 0.043478260869565216,
#  ('Merzig Wadern', 'no'): 0.6896551724137931,
#  ('Merzig Wadern', 'negotiable'): 0.1724137931034483,
#  ('Merzig Wadern', 'yes'): 0.13793103448275862,
#  ('Mettmann', 'negotiable'): 0.5805714285714285,
#  ('Mettmann', 'no'): 0.3588571428571429,
#  ('Mettmann', 'yes'): 0.060571428571428575,
#  ('Miesbach', 'no'): 0.5462184873949579,
#  ('Miesbach', 'negotiable'): 0.3865546218487395,
#  ('Miesbach', 'yes'): 0.06722689075630252,
#  ('Miltenberg', 'no'): 0.6708860759493671,
#  ('Miltenberg', 'negotiable'): 0.24050632911392406,
#  ('Miltenberg', 'yes'): 0.08860759493670886,
#  ('Minden Lübbecke', 'no'): 0.5318471337579618,
#  ('Minden Lübbecke', 'negotiable'): 0.4394904458598726,
#  ('Minden Lübbecke', 'yes'): 0.028662420382165606,
#  ('Mittelsachsen', 'negotiable'): 0.8023986293546544,
#  ('Mittelsachsen', 'yes'): 0.143917761279269,
#  ('Mittelsachsen', 'no'): 0.05368360936607653,
#  ('Märkisch Oderland', 'negotiable'): 0.8247422680412371,
#  ('Märkisch Oderland', 'no'): 0.14948453608247422,
#  ('Märkisch Oderland', 'yes'): 0.02577319587628866,
#  ('Märkischer', 'negotiable'): 0.6641318124207858,
#  ('Märkischer', 'no'): 0.2674271229404309,
#  ('Märkischer', 'yes'): 0.06844106463878327,
#  ('Mönchengladbach', 'negotiable'): 0.5358288770053476,
#  ('Mönchengladbach', 'no'): 0.40855614973262033,
#  ('Mönchengladbach', 'yes'): 0.05561497326203209,
#  ('Mühldorf am Inn', 'negotiable'): 0.5306122448979592,
#  ('Mühldorf am Inn', 'no'): 0.42857142857142855,
#  ('Mühldorf am Inn', 'yes'): 0.04081632653061224,
#  ('Mülheim an der Ruhr', 'negotiable'): 0.6196581196581197,
#  ('Mülheim an der Ruhr', 'no'): 0.33760683760683763,
#  ('Mülheim an der Ruhr', 'yes'): 0.042735042735042736,
#  ('München', 'no'): 0.595400646784046,
#  ('München', 'negotiable'): 0.36435501257635644,
#  ('München', 'yes'): 0.04024434063959756,
#  ('Münster', 'no'): 0.7037037037037037,
#  ('Münster', 'negotiable'): 0.27469135802469136,
#  ('Münster', 'yes'): 0.021604938271604937,
#  ('Müritz', 'negotiable'): 0.5301204819277109,
#  ('Müritz', 'no'): 0.27710843373493976,
#  ('Müritz', 'yes'): 0.1927710843373494,
#  ('Neckar Odenwald', 'no'): 0.7543859649122807,
#  ('Neckar Odenwald', 'negotiable'): 0.21052631578947367,
#  ('Neckar Odenwald', 'yes'): 0.03508771929824561,
#  ('Neu Ulm', 'no'): 0.7551020408163265,
#  ('Neu Ulm', 'negotiable'): 0.21428571428571427,
#  ('Neu Ulm', 'yes'): 0.030612244897959183,
#  ('Neubrandenburg', 'negotiable'): 0.63125,
#  ('Neubrandenburg', 'no'): 0.2625,
#  ('Neubrandenburg', 'yes'): 0.10625,
#  ('Neuburg Schrobenhausen', 'no'): 0.6355140186915887,
#  ('Neuburg Schrobenhausen', 'negotiable'): 0.3364485981308411,
#  ('Neuburg Schrobenhausen', 'yes'): 0.028037383177570093,
#  ('Neumarkt in der Oberpfalz', 'no'): 0.65,
#  ('Neumarkt in der Oberpfalz', 'negotiable'): 0.35,
#  ('Neumünster', 'negotiable'): 0.7383177570093458,
#  ('Neumünster', 'no'): 0.2336448598130841,
#  ('Neumünster', 'yes'): 0.028037383177570093,
#  ('Neunkirchen', 'negotiable'): 0.4657534246575342,
#  ('Neunkirchen', 'no'): 0.410958904109589,
#  ('Neunkirchen', 'yes'): 0.1232876712328767,
#  ('Neuss Rhein', 'negotiable'): 0.49934810951760106,
#  ('Neuss Rhein', 'no'): 0.45371577574967403,
#  ('Neuss Rhein', 'yes'): 0.0469361147327249,
#  ('Neustadt a.d. Aisch Bad Windsheim', 'no'): 0.6470588235294118,
#  ('Neustadt a.d. Aisch Bad Windsheim', 'negotiable'): 0.23529411764705882,
#  ('Neustadt a.d. Aisch Bad Windsheim', 'yes'): 0.11764705882352941,
#  ('Neustadt a.d. Waldnaab', 'negotiable'): 0.8571428571428571,
#  ('Neustadt a.d. Waldnaab', 'yes'): 0.14285714285714285,
#  ('Neustadt an der Weinstrasse', 'no'): 0.5,
#  ('Neustadt an der Weinstrasse', 'negotiable'): 0.45652173913043476,
#  ('Neustadt an der Weinstrasse', 'yes'): 0.043478260869565216,
#  ('Neuwied', 'no'): 0.6011560693641619,
#  ('Neuwied', 'negotiable'): 0.3468208092485549,
#  ('Neuwied', 'yes'): 0.05202312138728324,
#  ('Nienburg Weser', 'no'): 0.6470588235294118,
#  ('Nienburg Weser', 'negotiable'): 0.3382352941176471,
#  ('Nienburg Weser', 'yes'): 0.014705882352941176,
#  ('Nordfriesland', 'negotiable'): 0.5625,
#  ('Nordfriesland', 'no'): 0.4,
#  ('Nordfriesland', 'yes'): 0.0375,
#  ('Nordhausen', 'negotiable'): 0.861003861003861,
#  ('Nordhausen', 'no'): 0.11196911196911197,
#  ('Nordhausen', 'yes'): 0.02702702702702703,
#  ('Nordsachsen', 'negotiable'): 0.8123953098827471,
#  ('Nordsachsen', 'yes'): 0.10385259631490787,
#  ('Nordsachsen', 'no'): 0.08375209380234507,
#  ('Nordvorpommern', 'negotiable'): 0.6914498141263941,
#  ('Nordvorpommern', 'no'): 0.25650557620817843,
#  ('Nordvorpommern', 'yes'): 0.05204460966542751,
#  ('Nordwestmecklenburg', 'negotiable'): 0.8377358490566038,
#  ('Nordwestmecklenburg', 'no'): 0.1471698113207547,
#  ('Nordwestmecklenburg', 'yes'): 0.01509433962264151,
#  ('Northeim', 'negotiable'): 0.8380952380952381,
#  ('Northeim', 'no'): 0.12380952380952381,
#  ('Northeim', 'yes'): 0.0380952380952381,
#  ('Nürnberg', 'no'): 0.571304347826087,
#  ('Nürnberg', 'negotiable'): 0.3947826086956522,
#  ('Nürnberg', 'yes'): 0.03391304347826087,
#  ('Nürnberger Land', 'no'): 0.5352112676056338,
#  ('Nürnberger Land', 'negotiable'): 0.39436619718309857,
#  ('Nürnberger Land', 'yes'): 0.07042253521126761,
#  ('Oberallgäu', 'no'): 0.5970149253731343,
#  ('Oberallgäu', 'negotiable'): 0.31343283582089554,
#  ('Oberallgäu', 'yes'): 0.08955223880597014,
#  ('Oberbergischer', 'negotiable'): 0.5537974683544303,
#  ('Oberbergischer', 'no'): 0.40822784810126583,
#  ('Oberbergischer', 'yes'): 0.0379746835443038,
#  ('Oberhausen', 'negotiable'): 0.7254004576659039,
#  ('Oberhausen', 'no'): 0.2448512585812357,
#  ('Oberhausen', 'yes'): 0.029748283752860413,
#  ('Oberhavel', 'negotiable'): 0.6881188118811881,
#  ('Oberhavel', 'no'): 0.24257425742574257,
#  ('Oberhavel', 'yes'): 0.06930693069306931,
#  ('Oberspreewald Lausitz', 'negotiable'): 0.65,
#  ('Oberspreewald Lausitz', 'no'): 0.26153846153846155,
#  ('Oberspreewald Lausitz', 'yes'): 0.08846153846153847,
#  ('Odenwaldkreis', 'no'): 0.5652173913043478,
#  ('Odenwaldkreis', 'negotiable'): 0.2608695652173913,
#  ('Odenwaldkreis', 'yes'): 0.17391304347826086,
#  ('Oder Spree', 'negotiable'): 0.7806122448979592,
#  ('Oder Spree', 'yes'): 0.12755102040816327,
#  ('Oder Spree', 'no'): 0.09183673469387756,
#  ('Offenbach', 'no'): 0.5049088359046283,
#  ('Offenbach', 'negotiable'): 0.45021037868162694,
#  ('Offenbach', 'yes'): 0.04488078541374474,
#  ('Offenbach am Main', 'negotiable'): 0.5729442970822282,
#  ('Offenbach am Main', 'no'): 0.4005305039787798,
#  ('Offenbach am Main', 'yes'): 0.026525198938992044,
#  ('Oldenburg', 'no'): 0.7083333333333334,
#  ('Oldenburg', 'negotiable'): 0.2708333333333333,
#  ('Oldenburg', 'yes'): 0.020833333333333332,
#  ('Oldenburg Oldenburg', 'no'): 0.5909090909090909,
#  ('Oldenburg Oldenburg', 'negotiable'): 0.38636363636363635,
#  ('Oldenburg Oldenburg', 'yes'): 0.022727272727272728,
#  ('Olpe', 'no'): 0.6507936507936508,
#  ('Olpe', 'negotiable'): 0.3333333333333333,
#  ('Olpe', 'yes'): 0.015873015873015872,
#  ('Ortenaukreis', 'no'): 0.5063829787234042,
#  ('Ortenaukreis', 'negotiable'): 0.43829787234042555,
#  ('Ortenaukreis', 'yes'): 0.05531914893617021,
#  ('Osnabrück', 'no'): 0.6200527704485488,
#  ('Osnabrück', 'negotiable'): 0.3245382585751979,
#  ('Osnabrück', 'yes'): 0.055408970976253295,
#  ('Ostalbkreis', 'no'): 0.7847222222222222,
#  ('Ostalbkreis', 'negotiable'): 0.16666666666666666,
#  ('Ostalbkreis', 'yes'): 0.04861111111111111,
#  ('Ostallgäu', 'no'): 0.703125,
#  ('Ostallgäu', 'negotiable'): 0.28125,
#  ('Ostallgäu', 'yes'): 0.015625,
#  ('Osterholz', 'negotiable'): 0.611764705882353,
#  ('Osterholz', 'no'): 0.36470588235294116,
#  ('Osterholz', 'yes'): 0.023529411764705882,
#  ('Osterode am Harz', 'negotiable'): 0.8333333333333334,
#  ('Osterode am Harz', 'no'): 0.13690476190476192,
#  ('Osterode am Harz', 'yes'): 0.02976190476190476,
#  ('Ostholstein', 'negotiable'): 0.5722543352601156,
#  ('Ostholstein', 'no'): 0.35260115606936415,
#  ('Ostholstein', 'yes'): 0.07514450867052024,
#  ('Ostprignitz Ruppin', 'no'): 0.4823529411764706,
#  ('Ostprignitz Ruppin', 'negotiable'): 0.4117647058823529,
#  ('Ostprignitz Ruppin', 'yes'): 0.10588235294117647,
#  ('Ostvorpommern', 'negotiable'): 0.7464788732394366,
#  ('Ostvorpommern', 'no'): 0.2112676056338028,
#  ('Ostvorpommern', 'yes'): 0.04225352112676056,
#  ('Paderborn', 'no'): 0.7146892655367232,
#  ('Paderborn', 'negotiable'): 0.2344632768361582,
#  ('Paderborn', 'yes'): 0.05084745762711865,
#  ('Parchim', 'negotiable'): 0.8395061728395061,
#  ('Parchim', 'no'): 0.08641975308641975,
#  ('Parchim', 'yes'): 0.07407407407407407,
#  ('Passau', 'no'): 0.6265432098765432,
#  ('Passau', 'negotiable'): 0.3395061728395062,
#  ('Passau', 'yes'): 0.033950617283950615,
#  ('Peine', 'no'): 0.5343511450381679,
#  ('Peine', 'negotiable'): 0.4351145038167939,
#  ('Peine', 'yes'): 0.030534351145038167,
#  ('Pfaffenhofen an der Ilm', 'no'): 0.6708074534161491,
#  ('Pfaffenhofen an der Ilm', 'negotiable'): 0.2795031055900621,
#  ('Pfaffenhofen an der Ilm', 'yes'): 0.049689440993788817,
#  ('Pforzheim', 'no'): 0.7342342342342343,
#  ('Pforzheim', 'negotiable'): 0.23423423423423423,
#  ('Pforzheim', 'yes'): 0.03153153153153153,
#  ('Pinneberg', 'negotiable'): 0.5711422845691383,
#  ('Pinneberg', 'no'): 0.39879759519038077,
#  ('Pinneberg', 'yes'): 0.03006012024048096,
#  ('Pirmasens', 'negotiable'): 0.5370370370370371,
#  ('Pirmasens', 'no'): 0.4166666666666667,
#  ('Pirmasens', 'yes'): 0.046296296296296294,
#  ('Plauen', 'negotiable'): 0.8822115384615384,
#  ('Plauen', 'yes'): 0.07091346153846154,
#  ('Plauen', 'no'): 0.046875,
#  ('Plön', 'negotiable'): 0.6413043478260869,
#  ('Plön', 'no'): 0.31521739130434784,
#  ('Plön', 'yes'): 0.043478260869565216,
#  ('Potsdam', 'negotiable'): 0.8154981549815498,
#  ('Potsdam', 'no'): 0.16974169741697417,
#  ('Potsdam', 'yes'): 0.014760147601476014,
#  ('Potsdam Mittelmark', 'negotiable'): 0.7854251012145749,
#  ('Potsdam Mittelmark', 'no'): 0.145748987854251,
#  ('Potsdam Mittelmark', 'yes'): 0.06882591093117409,
#  ('Prignitz', 'negotiable'): 0.41605839416058393,
#  ('Prignitz', 'no'): 0.41605839416058393,
#  ('Prignitz', 'yes'): 0.1678832116788321,
#  ('Rastatt', 'negotiable'): 0.4930555555555556,
#  ('Rastatt', 'no'): 0.4652777777777778,
#  ('Rastatt', 'yes'): 0.041666666666666664,
#  ('Ravensburg', 'no'): 0.8515625,
#  ('Ravensburg', 'negotiable'): 0.140625,
#  ('Ravensburg', 'yes'): 0.0078125,
#  ('Recklinghausen', 'negotiable'): 0.6235912847483095,
#  ('Recklinghausen', 'no'): 0.2930127723516153,
#  ('Recklinghausen', 'yes'): 0.08339594290007513,
#  ('Regen', 'no'): 0.45161290322580644,
#  ('Regen', 'negotiable'): 0.41935483870967744,
#  ('Regen', 'yes'): 0.12903225806451613,
#  ('Regensburg', 'no'): 0.688034188034188,
#  ('Regensburg', 'negotiable'): 0.2841880341880342,
#  ('Regensburg', 'yes'): 0.027777777777777776,
#  ('Rems Murr', 'no'): 0.6892430278884463,
#  ('Rems Murr', 'negotiable'): 0.27091633466135456,
#  ('Rems Murr', 'yes'): 0.0398406374501992,
#  ('Remscheid', 'negotiable'): 0.721763085399449,
#  ('Remscheid', 'no'): 0.22589531680440772,
#  ('Remscheid', 'yes'): 0.05234159779614325,
#  ('Rendsburg Eckernförde', 'negotiable'): 0.5952380952380952,
#  ('Rendsburg Eckernförde', 'no'): 0.36394557823129253,
#  ('Rendsburg Eckernförde', 'yes'): 0.04081632653061224,
#  ('Reutlingen', 'no'): 0.7031963470319634,
#  ('Reutlingen', 'negotiable'): 0.273972602739726,
#  ('Reutlingen', 'yes'): 0.0228310502283105,
#  ('Rhein Erft', 'negotiable'): 0.48230668414154654,
#  ('Rhein Erft', 'no'): 0.4600262123197903,
#  ('Rhein Erft', 'yes'): 0.057667103538663174,
#  ('Rhein Hunsrück', 'no'): 0.5789473684210527,
#  ('Rhein Hunsrück', 'negotiable'): 0.42105263157894735,
#  ('Rhein Lahn', 'negotiable'): 0.4869109947643979,
#  ('Rhein Lahn', 'no'): 0.47643979057591623,
#  ('Rhein Lahn', 'yes'): 0.03664921465968586,
#  ('Rhein Neckar', 'no'): 0.6216216216216216,
#  ('Rhein Neckar', 'negotiable'): 0.3497615262321145,
#  ('Rhein Neckar', 'yes'): 0.028616852146263912,
#  ('Rhein Pfalz', 'no'): 0.6454545454545455,
#  ('Rhein Pfalz', 'negotiable'): 0.3090909090909091,
#  ('Rhein Pfalz', 'yes'): 0.045454545454545456,
#  ('Rhein Sieg', 'no'): 0.524,
#  ('Rhein Sieg', 'negotiable'): 0.43866666666666665,
#  ('Rhein Sieg', 'yes'): 0.037333333333333336,
#  ('Rheingau Taunus', 'no'): 0.5094736842105263,
#  ('Rheingau Taunus', 'negotiable'): 0.4357894736842105,
#  ('Rheingau Taunus', 'yes'): 0.05473684210526316,
#  ('Rheinisch Bergischer', 'negotiable'): 0.522140221402214,
#  ('Rheinisch Bergischer', 'no'): 0.42435424354243545,
#  ('Rheinisch Bergischer', 'yes'): 0.05350553505535055,
#  ('Rhön Grabfeld', 'no'): 0.4,
#  ('Rhön Grabfeld', 'negotiable'): 0.3333333333333333,
#  ('Rhön Grabfeld', 'yes'): 0.26666666666666666,
#  ('Rosenheim', 'no'): 0.632768361581921,
#  ('Rosenheim', 'negotiable'): 0.327683615819209,
#  ('Rosenheim', 'yes'): 0.03954802259887006,
#  ('Rostock', 'negotiable'): 0.7493670886075949,
#  ('Rostock', 'no'): 0.22531645569620254,
#  ('Rostock', 'yes'): 0.02531645569620253,
#  ('Rotenburg Wümme', 'negotiable'): 0.5789473684210527,
#  ('Rotenburg Wümme', 'no'): 0.38596491228070173,
#  ('Rotenburg Wümme', 'yes'): 0.03508771929824561,
#  ('Roth', 'no'): 0.5957446808510638,
#  ('Roth', 'negotiable'): 0.3829787234042553,
#  ('Roth', 'yes'): 0.02127659574468085,
#  ('Rottal Inn', 'no'): 0.6176470588235294,
#  ('Rottal Inn', 'negotiable'): 0.3235294117647059,
#  ('Rottal Inn', 'yes'): 0.058823529411764705,
#  ('Rottweil', 'no'): 0.7073170731707317,
#  ('Rottweil', 'negotiable'): 0.2073170731707317,
#  ('Rottweil', 'yes'): 0.08536585365853659,
#  ('Rügen', 'negotiable'): 0.8321167883211679,
#  ('Rügen', 'no'): 0.0948905109489051,
#  ('Rügen', 'yes'): 0.072992700729927,
#  ('Saale Holzland', 'yes'): 0.5454545454545454,
#  ('Saale Holzland', 'negotiable'): 0.29292929292929293,
#  ('Saale Holzland', 'no'): 0.16161616161616163,
#  ('Saale Orla', 'negotiable'): 0.9473684210526315,
#  ('Saale Orla', 'no'): 0.05263157894736842,
#  ('Saalekreis', 'negotiable'): 0.663013698630137,
#  ('Saalekreis', 'yes'): 0.2958904109589041,
#  ('Saalekreis', 'no'): 0.0410958904109589,
#  ('Saalfeld Rudolstadt', 'negotiable'): 0.8227848101265823,
#  ('Saalfeld Rudolstadt', 'no'): 0.10126582278481013,
#  ('Saalfeld Rudolstadt', 'yes'): 0.0759493670886076,
#  ('Saarbrücken', 'no'): 0.49645390070921985,
#  ('Saarbrücken', 'negotiable'): 0.4302600472813239,
#  ('Saarbrücken', 'yes'): 0.07328605200945626,
#  ('Saarlouis', 'no'): 0.6836734693877551,
#  ('Saarlouis', 'negotiable'): 0.20408163265306123,
#  ('Saarlouis', 'yes'): 0.11224489795918367,
#  ('Saarpfalz', 'no'): 0.5526315789473685,
#  ('Saarpfalz', 'negotiable'): 0.38596491228070173,
#  ('Saarpfalz', 'yes'): 0.06140350877192982,
#  ('Salzgitter', 'negotiable'): 0.7637795275590551,
#  ('Salzgitter', 'no'): 0.18110236220472442,
#  ('Salzgitter', 'yes'): 0.05511811023622047,
#  ('Salzlandkreis', 'negotiable'): 0.764525993883792,
#  ('Salzlandkreis', 'yes'): 0.11926605504587157,
#  ('Salzlandkreis', 'no'): 0.1162079510703364,
#  ('Sankt Wendel', 'no'): 0.5384615384615384,
#  ('Sankt Wendel', 'negotiable'): 0.46153846153846156,
#  ('Schaumburg', 'no'): 0.49238578680203043,
#  ('Schaumburg', 'negotiable'): 0.4720812182741117,
#  ('Schaumburg', 'yes'): 0.03553299492385787,
#  ('Schleswig Flensburg', 'negotiable'): 0.72,
#  ('Schleswig Flensburg', 'no'): 0.2088888888888889,
#  ('Schleswig Flensburg', 'yes'): 0.07111111111111111,
#  ('Schmalkalden Meiningen', 'negotiable'): 0.6717557251908397,
#  ('Schmalkalden Meiningen', 'no'): 0.29770992366412213,
#  ('Schmalkalden Meiningen', 'yes'): 0.030534351145038167,
#  ('Schwabach', 'no'): 0.5789473684210527,
#  ('Schwabach', 'negotiable'): 0.3684210526315789,
#  ('Schwabach', 'yes'): 0.05263157894736842,
#  ('Schwalm Eder', 'negotiable'): 0.6153846153846154,
#  ('Schwalm Eder', 'no'): 0.32051282051282054,
#  ('Schwalm Eder', 'yes'): 0.0641025641025641,
#  ('Schwandorf', 'no'): 0.6153846153846154,
#  ('Schwandorf', 'negotiable'): 0.34615384615384615,
#  ('Schwandorf', 'yes'): 0.038461538461538464,
#  ('Schwarzwald Baar', 'no'): 0.5806451612903226,
#  ('Schwarzwald Baar', 'negotiable'): 0.33064516129032256,
#  ('Schwarzwald Baar', 'yes'): 0.08870967741935484,
#  ('Schweinfurt', 'no'): 0.7714285714285715,
#  ('Schweinfurt', 'negotiable'): 0.17142857142857143,
#  ('Schweinfurt', 'yes'): 0.05714285714285714,
#  ('Schwerin', 'negotiable'): 0.6828571428571428,
#  ('Schwerin', 'no'): 0.2057142857142857,
#  ('Schwerin', 'yes'): 0.11142857142857143,
#  ('Schwäbisch Hall', 'no'): 0.6592592592592592,
#  ('Schwäbisch Hall', 'negotiable'): 0.2814814814814815,
#  ('Schwäbisch Hall', 'yes'): 0.05925925925925926,
#  ('Segeberg', 'negotiable'): 0.6534391534391535,
#  ('Segeberg', 'no'): 0.2962962962962963,
#  ('Segeberg', 'yes'): 0.05026455026455026,
#  ('Siegen Wittgenstein', 'no'): 0.5514705882352942,
#  ('Siegen Wittgenstein', 'negotiable'): 0.4264705882352941,
#  ('Siegen Wittgenstein', 'yes'): 0.022058823529411766,
#  ('Sigmaringen', 'no'): 0.6060606060606061,
#  ('Sigmaringen', 'negotiable'): 0.2727272727272727,
#  ('Sigmaringen', 'yes'): 0.12121212121212122,
#  ('Soest', 'no'): 0.535593220338983,
#  ('Soest', 'negotiable'): 0.4440677966101695,
#  ('Soest', 'yes'): 0.020338983050847456,
#  ('Solingen', 'negotiable'): 0.5574837310195228,
#  ('Solingen', 'no'): 0.3839479392624729,
#  ('Solingen', 'yes'): 0.05856832971800434,
#  ('Soltau Fallingbostel', 'no'): 0.45,
#  ('Soltau Fallingbostel', 'negotiable'): 0.375,
#  ('Soltau Fallingbostel', 'yes'): 0.175,
#  ('Sonneberg', 'negotiable'): 0.7457627118644068,
#  ('Sonneberg', 'no'): 0.23728813559322035,
#  ('Sonneberg', 'yes'): 0.01694915254237288,
#  ('Speyer', 'no'): 0.5645161290322581,
#  ('Speyer', 'negotiable'): 0.3387096774193548,
#  ('Speyer', 'yes'): 0.0967741935483871,
#  ('Spree Neisse', 'negotiable'): 0.8349514563106796,
#  ('Spree Neisse', 'yes'): 0.12135922330097088,
#  ('Spree Neisse', 'no'): 0.043689320388349516,
#  ('Stade', 'negotiable'): 0.5477031802120141,
#  ('Stade', 'no'): 0.42402826855123676,
#  ('Stade', 'yes'): 0.028268551236749116,
#  ('Starnberg', 'no'): 0.54,
#  ('Starnberg', 'negotiable'): 0.4,
#  ('Starnberg', 'yes'): 0.06,
#  ('Steinburg', 'negotiable'): 0.7092198581560284,
#  ('Steinburg', 'no'): 0.19148936170212766,
#  ('Steinburg', 'yes'): 0.09929078014184398,
#  ('Steinfurt', 'no'): 0.6554054054054054,
#  ('Steinfurt', 'negotiable'): 0.3141891891891892,
#  ('Steinfurt', 'yes'): 0.030405405405405407,
#  ('Stendal', 'negotiable'): 0.6336336336336337,
#  ('Stendal', 'yes'): 0.2072072072072072,
#  ('Stendal', 'no'): 0.15915915915915915,
#  ('Stormarn', 'negotiable'): 0.6313725490196078,
#  ('Stormarn', 'no'): 0.30980392156862746,
#  ('Stormarn', 'yes'): 0.058823529411764705,
#  ('Stralsund', 'negotiable'): 0.7988505747126436,
#  ('Stralsund', 'no'): 0.16091954022988506,
#  ('Stralsund', 'yes'): 0.040229885057471264,
#  ('Straubing', 'no'): 0.7301587301587301,
#  ('Straubing', 'negotiable'): 0.25396825396825395,
#  ('Straubing', 'yes'): 0.015873015873015872,
#  ...}

# %%
#Here we calcuate the percentage of appartments containing a balcony
percentageofbalcony = app_city['balcony'].value_counts(normalize=True) #.to_frame()
percentageofbalcony
percentageofbalcony.rename["balcony"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2764/2330714784.py in <module>
#       2 percentageofbalcony = app_city['balcony'].value_counts(normalize=True) #.to_frame()
#       3 percentageofbalcony
# ----> 4 percentageofbalcony.rename["balcony"]
#
# TypeError: 'method' object is not subscriptable

# %%
app_city['balcony'].value_counts(normalize=True).reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10292/1729010258.py in <module>
# ----> 1 app_city['balcony'].value_counts(normalize=True).reset_index()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in reset_index(self, level, drop, name, inplace)
#    1440         else:
#    1441             df = self.to_frame(name)
# -> 1442             return df.reset_index(level=level, drop=drop)
#    1443
#    1444     # ----------------------------------------------------------------------
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5797                     )
#    5798
# -> 5799                 new_obj.insert(0, name, level_values)
#    5800
#    5801         new_obj.index = new_index
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    4412         if not allow_duplicates and column in self.columns:
#    4413             # Should this be a different kind of error??
# -> 4414             raise ValueError(f"cannot insert {column}, already exists")
#    4415         if not isinstance(loc, int):
#    4416             raise TypeError("loc must be int")
#
# ValueError: cannot insert balcony, already exists

# %%
percentagebalcony.reset_index(drop=False, inplace=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10292/4162995900.py in <module>
# ----> 1 percentageofbalcony.reset_index(drop=False, inplace=False)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in reset_index(self, level, drop, name, inplace)
#    1440         else:
#    1441             df = self.to_frame(name)
# -> 1442             return df.reset_index(level=level, drop=drop)
#    1443
#    1444     # ----------------------------------------------------------------------
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5797                     )
#    5798
# -> 5799                 new_obj.insert(0, name, level_values)
#    5800
#    5801         new_obj.index = new_index
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    4412         if not allow_duplicates and column in self.columns:
#    4413             # Should this be a different kind of error??
# -> 4414             raise ValueError(f"cannot insert {column}, already exists")
#    4415         if not isinstance(loc, int):
#    4416             raise TypeError("loc must be int")
#
# ValueError: cannot insert balcony, already exists

# %%
filt_test=percentageofbalcony["balcony"]==False

percentageofbalcony.drop(index=percentageofbalcony[filt_test].index, inplace=True)
percentageofbalcony
# Out:
#                             balcony
# regio2            balcony
# Aachen            True     0.617223
#                   False    0.382777
# Ahrweiler         True     0.753943
#                   False    0.246057
# Aichach Friedberg True     0.824427
# ...                             ...
# Zollernalbkreis   False    0.385135
# Zweibrücken       False    0.630952
#                   True     0.369048
# Zwickau           False    0.527280
#                   True     0.472720
#
# [788 rows x 1 columns]

# %%
percentageofbalcony = percentageofbalcony.drop(percentageofbalcony["balcony"==True].index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10292/2088369279.py in <module>
# ----> 1 percentageofbalcony = percentageofbalcony.drop(percentageofbalcony["balcony"==True].index)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\multi.py in get_loc(self, key, method)
#    2920
#    2921         if not isinstance(key, tuple):
# -> 2922             loc = self._get_level_indexer(key, level=0)
#    2923             return _maybe_to_slice(loc)
#    2924
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\multi.py in _get_level_indexer(self, key, level, indexer)
#    3202         else:
#    3203
# -> 3204             idx = self._get_loc_single_level_index(level_index, key)
#    3205
#    3206             if level > 0 or self._lexsort_depth == 0:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\multi.py in _get_loc_single_level_index(self, level_index, key)
#    2853             return -1
#    2854         else:
# -> 2855             return level_index.get_loc(key)
#    2856
#    2857     def get_loc(self, key, method=None):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: False

# %%
percentageoftruebalcony= percentageofbalcony.filter(items=["balcony"==True])
percentageoftruebalcony
# Out:
# Series([], Name: balcony, dtype: float64)

# %%
filt_balcony=(app_city["balcony"]==True)

percentageofbalcony[filt_balcony]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10292/3487971524.py in <module>
#       1 filt_balcony=(app_city["balcony"]==True)
#       2
# ----> 3 percentageofbalcony[filt_balcony]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\multi.py in get_loc(self, key, method)
#    2920
#    2921         if not isinstance(key, tuple):
# -> 2922             loc = self._get_level_indexer(key, level=0)
#    2923             return _maybe_to_slice(loc)
#    2924
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\multi.py in _get_level_indexer(self, key, level, indexer)
#    3202         else:
#    3203
# -> 3204             idx = self._get_loc_single_level_index(level_index, key)
#    3205
#    3206             if level > 0 or self._lexsort_depth == 0:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\multi.py in _get_loc_single_level_index(self, level_index, key)
#    2853             return -1
#    2854         else:
# -> 2855             return level_index.get_loc(key)
#    2856
#    2857     def get_loc(self, key, method=None):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: False

# %%
#We merge the percentageofbalcony to the uni_cities DataFrame as new column
uni_cities.merge(fertig, right_index=True, left_on="city", how="left")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10292/3490284330.py in <module>
#       1 #We merge the percentageofbalcony to the uni_cities DataFrame as new column
# ----> 2 uni_cities.merge(fertig, right_index=True, left_on="city", how="left")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9188         from pandas.core.reshape.merge import merge
#    9189
# -> 9190         return merge(
#    9191             self,
#    9192             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     701         # validate the merge keys dtypes. We may need to coerce
#     702         # to avoid incompatible dtypes
# --> 703         self._maybe_coerce_merge_keys()
#     704
#     705         # If argument passed to validate,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _maybe_coerce_merge_keys(self)
#    1254                     inferred_right in string_types and inferred_left not in string_types
#    1255                 ):
# -> 1256                     raise ValueError(msg)
#    1257
#    1258             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %% [markdown]
# The mean base rent

# %%
#Here we save the grouping of the base rent by city as "meanofbaseRent"
meanofbaseRent=app_city["baseRent"].mean()
meanofbaseRent
# Out:
# regio2
# Aachen               632.835178
# Ahrweiler            649.028864
# Aichach Friedberg    874.308092
# Alb Donau            766.675130
# Altenburger Land     325.581940
#                         ...
# Wuppertal            484.485008
# Würzburg             762.524601
# Zollernalbkreis      655.661486
# Zweibrücken          446.357143
# Zwickau              338.527671
# Name: baseRent, Length: 394, dtype: float64

# %%
#We merge the meanofbaseRent to the uni_cities DataFrame as new column
uni_cities=uni_cities.merge(meanofbaseRent, right_index=True, left_on="city", how="left")

# %% [markdown]
# The median base rent

# %%
#Here we save the grouping of the base Rent by city as "medianofbaseRent"
medianofbaseRent=app_city["baseRent"].median()
medianofbaseRent
# Out:
# regio2
# Aachen               570.0
# Ahrweiler            570.0
# Aichach Friedberg    795.0
# Alb Donau            750.0
# Altenburger Land     300.0
#                      ...
# Wuppertal            420.0
# Würzburg             737.5
# Zollernalbkreis      650.0
# Zweibrücken          412.5
# Zwickau              301.0
# Name: baseRent, Length: 394, dtype: float64

# %%
#We merge the medianofbaseRent to the uni_cities DataFrame as new column
uni_cities=uni_cities.merge(medianofbaseRent, right_index=True, left_on="city", how="left")

# %% [markdown]
# The mean living space

# %%
#Here we save the grouping of the living space by city as "meanoflivingSpace"
meanoflivingSpace=app_city["livingSpace"].mean()
meanoflivingSpace
# Out:
# regio2
# Aachen               72.709100
# Ahrweiler            83.978013
# Aichach Friedberg    88.872290
# Alb Donau            85.743368
# Altenburger Land     63.751907
#                        ...
# Wuppertal            70.879882
# Würzburg             72.218859
# Zollernalbkreis      84.952432
# Zweibrücken          76.940000
# Zwickau              63.899057
# Name: livingSpace, Length: 394, dtype: float64

# %%
#We merge the meanoflivingSpace to the uni_cities DataFrame as new column
uni_cities=uni_cities.merge(meanoflivingSpace, right_index=True, left_on="city", how="left")

# %% [markdown]
# The median living space

# %%
#Here we save the grouping of living space by city as "medianoflivingSpace"
medianoflivingSpace=app_city["livingSpace"].median()
medianoflivingSpace
# Out:
# regio2
# Aachen               70.00
# Ahrweiler            78.00
# Aichach Friedberg    85.00
# Alb Donau            84.00
# Altenburger Land     60.60
#                      ...
# Wuppertal            67.32
# Würzburg             70.00
# Zollernalbkreis      82.50
# Zweibrücken          77.50
# Zwickau              60.00
# Name: livingSpace, Length: 394, dtype: float64

# %%
#We merge the medianoflivingSpace to the uni_cities DataFrame as new column
uni_cities=uni_cities.merge(medianoflivingSpace, right_index=True, left_on="city", how="left")

# %% [markdown]
# The mean no. of rooms

# %%
#Here we save the grouping of the no of rooms by city as "noRooms"
meanofnoRooms=app_city["noRooms"].mean()
meanofnoRooms
# Out:
# regio2
# Aachen               2.516520
# Ahrweiler            2.679811
# Aichach Friedberg    3.015267
# Alb Donau            3.023316
# Altenburger Land     2.506633
#                        ...
# Wuppertal            2.493708
# Würzburg             2.463225
# Zollernalbkreis      2.979730
# Zweibrücken          2.690476
# Zwickau              2.457381
# Name: noRooms, Length: 394, dtype: float64

# %%
#We merge the meanofnoRooms to the uni_cities DataFrame as new column
uni_cities=uni_cities.merge(meanofnoRooms, right_index=True, left_on="city", how="left")

# %% [markdown]
# The median no. of rooms

# %%
#Here we save the grouping of no of rooms by city as "medianofnoRooms"
medianofnoRooms=app_city["noRooms"].median()
medianofnoRooms
# Out:
# regio2
# Aachen               2.5
# Ahrweiler            3.0
# Aichach Friedberg    3.0
# Alb Donau            3.0
# Altenburger Land     2.0
#                     ...
# Wuppertal            2.0
# Würzburg             2.5
# Zollernalbkreis      3.0
# Zweibrücken          3.0
# Zwickau              2.0
# Name: noRooms, Length: 394, dtype: float64

# %%
#We merge the medianofnoRooms to the uni_cities DataFrame as new column
uni_cities=uni_cities.merge(medianofnoRooms, right_index=True, left_on="city", how="left")

# %%
 ## Percentage of hasKitchen

# %%
#Here we save the percentages for appartments containing a kitchen as "percentageofhasKitchen"
percentageofhasKitchen = app_city['hasKitchen'].value_counts(normalize=True)

# %%
#We merge the percentageofhasKitchen to the uni_cities DataFrame as new column
uni_cities=uni_cities.merge(percentageofhasKitchen, right_index=True, left_on="city", how="left")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10292/1962983279.py in <module>
#       1 #We merge the percentageofhasKitchen to the uni_cities DataFrame as new column
# ----> 2 uni_cities=uni_cities.merge(percentageofhasKitchen, right_index=True, left_on="city", how="left")
#
# NameError: name 'percentageofhasKitchen' is not defined

# %%
## Percentage of cellar

# %%
#Here we save the percentages for appartments containing a cellar as "percentageofcellar"
percentageofcellar = app_city['cellar'].value_counts(normalize=True)
percentageofcellar
# Out:
# regio2             cellar
# Aachen             True      0.677680
#                    False     0.322320
# Ahrweiler          True      0.621451
#                    False     0.378549
# Aichach Friedberg  True      0.679389
#                                ...
# Zollernalbkreis    False     0.405405
# Zweibrücken        False     0.547619
#                    True      0.452381
# Zwickau            True      0.687461
#                    False     0.312539
# Name: cellar, Length: 788, dtype: float64

# %%
#We merge the percentageofcellar to the uni_cities DataFrame as new column
uni_cities=uni_cities.merge(percentageofcellar, right_index=True, left_on="city", how="left")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10292/2659423806.py in <module>
#       1 #We merge the percentageofcellar to the uni_cities DataFrame as new column
# ----> 2 uni_cities=uni_cities.merge(percentageofcellar, right_index=True, left_on="city", how="left")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9188         from pandas.core.reshape.merge import merge
#    9189
# -> 9190         return merge(
#    9191             self,
#    9192             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     679             warnings.warn(msg, FutureWarning, stacklevel=3)
#     680
# --> 681         self._validate_specification()
#     682
#     683         cross_col = None
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _validate_specification(self)
#    1379             if self.right_index:
#    1380                 if len(self.left_on) != self.right.index.nlevels:
# -> 1381                     raise ValueError(
#    1382                         "len(left_on) must equal the number "
#    1383                         'of levels in the index of "right"'
#
# ValueError: len(left_on) must equal the number of levels in the index of "right"

# %%
## Percentage of lift

# %%
#Here we save the percentages for appartments containing a lift as "percentageoflift"
percentageoflift = app_city['lift'].value_counts(normalize=True)
percentageoflift
# Out:
# regio2             lift
# Aachen             False    0.741652
#                    True     0.258348
# Ahrweiler          False    0.719243
#                    True     0.280757
# Aichach Friedberg  False    0.709924
#                               ...
# Zollernalbkreis    True     0.243243
# Zweibrücken        False    0.928571
#                    True     0.071429
# Zwickau            False    0.905909
#                    True     0.094091
# Name: lift, Length: 784, dtype: float64

# %%
#We merge the percentageoflift to the uni_cities DataFrame as new column
uni_cities=uni_cities.merge(percentageoflift, right_index=True, left_on="city", how="left")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10292/3289032970.py in <module>
#       1 #We merge the percentageoflift to the uni_cities DataFrame as new column
# ----> 2 uni_cities=uni_cities.merge(percentageoflift, right_index=True, left_on="city", how="left")
#
# NameError: name 'percentageoflift' is not defined

# %%
## Percentage of garden

# %%
#Here we save the percentages for appartments containing a garden as "percentageofgarden"
percentageofgarden = app_city['garden'].value_counts(normalize=True)
percentageofgarden
# Out:
# regio2             garden
# Aachen             False     0.776450
#                    True      0.223550
# Ahrweiler          False     0.776025
#                    True      0.223975
# Aichach Friedberg  False     0.725191
#                                ...
# Zollernalbkreis    True      0.290541
# Zweibrücken        False     0.928571
#                    True      0.071429
# Zwickau            False     0.762611
#                    True      0.237389
# Name: garden, Length: 788, dtype: float64

# %%
#We merge the percentageoflift to the uni_cities DataFrame as new column
uni_cities=uni_cities.merge(percentageoflift, right_index=True, left_on="city", how="left")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10292/3289032970.py in <module>
#       1 #We merge the percentageoflift to the uni_cities DataFrame as new column
# ----> 2 uni_cities=uni_cities.merge(percentageoflift, right_index=True, left_on="city", how="left")
#
# NameError: name 'percentageoflift' is not defined

# %%
uni_cities
#uni_cities.to_csv("data/final.csv")
uni_cities.to_excel("data/test.xlsx")

# %%
#end
